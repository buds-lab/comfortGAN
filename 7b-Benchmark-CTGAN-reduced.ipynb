# %%
# Notebooks
import nbimporter
import os
import sys

# Functions from src
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# Defined Functions
from utils import *

# Pandas, matplotlib, pickle, seaborn
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from statistics import mean
from collections import Counter
from ctgan import CTGANSynthesizer

random_state = 13

# %%
# global variables/constants
num_trials = 30
test_size_percentage = 0.2 # for CV within train split
fixed_depth = 10

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Occutherm

# %%
df_tcs_train = pd.read_pickle("data/occutherm/df_feature1_train_reduced.pkl") 
df_tcs_test = pd.read_pickle("data/occutherm/df_feature1_test_reduced.pkl")

# total count for instances per class: 818
print(df_tcs_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 10 columns):
# Temperature (Fahrenheit)       1508 non-null float64
# SkinTemperature                1508 non-null float64
# ClothingInsulation             1508 non-null float64
# Height(cm)                     1508 non-null float64
# Shoulder Circumference(cm)     1508 non-null float64
# Weight(lbs)                    1508 non-null float64
# Gender                         1508 non-null int64
# Temperature_outside            1508 non-null float64
# Humidity_outside               1508 non-null float64
# Discrete Thermal Comfort_TA    1508 non-null int64
# dtypes: float64(8), int64(2)
# memory usage: 117.9 KB
# None

# %% [markdown]
# ## Cresh

# %% [markdown]
# ## ASHRAE

# %%
df_ashrae_train = pd.read_pickle("data/ashrae/ashrae_train_reduced.pkl")
df_ashrae_test = pd.read_pickle("data/ashrae/ashrae_test_reduced.pkl")

print(df_ashrae_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46477 entries, 0 to 46476
# Data columns (total 7 columns):
# SET                          46477 non-null float64
# Clo                          46477 non-null float64
# Met                          46477 non-null float64
# Air temperature (¡C)         46477 non-null float64
# Relative humidity (%)        46477 non-null float64
# Air velocity (m/s)           46477 non-null float64
# Thermal sensation rounded    46477 non-null float64
# dtypes: float64(7)
# memory usage: 2.5 MB
# None

# %% [markdown]
# # Samplig synthetic datasets
#
# https://sdv-dev.github.io/CTGAN/
#
# https://github.com/sdv-dev/CTGAN

# %% [markdown]
# ## Occutherm
# Required samples
#
# | Model | -1 | 0 | 1 |
# |---|---|---|---|
# | SMOTE | 342 | 0 | 603 |
# | ADASYN | 247 | 0 | 621 |

# %%
discrete_columns_occutherm = [
    'Gender',
    'Discrete Thermal Comfort_TA'
]

ctgan_occutherm = CTGANSynthesizer()
ctgan_occutherm.fit(df_tcs_train, discrete_columns_occutherm)
save_pickle(ctgan_occutherm, "models/ctgan_occutherm_reduced.pkl")
# Out:
# Epoch 1, Loss G: 1.0212, Loss D: -0.0214
# Epoch 2, Loss G: 0.8884, Loss D: 0.0092
# Epoch 3, Loss G: 0.8281, Loss D: -0.0023
# Epoch 4, Loss G: 0.7858, Loss D: 0.0585
# Epoch 5, Loss G: 0.7447, Loss D: 0.0485
# Epoch 6, Loss G: 0.7176, Loss D: -0.0333
# Epoch 7, Loss G: 0.6489, Loss D: -0.0041
# Epoch 8, Loss G: 0.5759, Loss D: -0.0855
# Epoch 9, Loss G: 0.4882, Loss D: -0.1023
# Epoch 10, Loss G: 0.4135, Loss D: -0.0607
# Epoch 11, Loss G: 0.2339, Loss D: -0.1579
# Epoch 12, Loss G: 0.2064, Loss D: 0.0891
# Epoch 13, Loss G: 0.2617, Loss D: -0.0360
# Epoch 14, Loss G: 0.1553, Loss D: -0.0447
# Epoch 15, Loss G: 0.2053, Loss D: -0.0410
# Epoch 16, Loss G: 0.2413, Loss D: 0.0212
# Epoch 17, Loss G: 0.3197, Loss D: -0.0441
# Epoch 18, Loss G: 0.4104, Loss D: -0.1524
# Epoch 19, Loss G: 0.4262, Loss D: -0.3367
# Epoch 20, Loss G: 0.3004, Loss D: -0.2962
# Epoch 21, Loss G: 0.2703, Loss D: -0.1711
# Epoch 22, Loss G: 0.2682, Loss D: -0.1673
# Epoch 23, Loss G: 0.2166, Loss D: 0.1099
# Epoch 24, Loss G: 0.1745, Loss D: -0.0534
# Epoch 25, Loss G: 0.1675, Loss D: -0.0310
# Epoch 26, Loss G: 0.1496, Loss D: -0.0393
# Epoch 27, Loss G: 0.0873, Loss D: 0.1043
# Epoch 28, Loss G: -0.0023, Loss D: 0.2437
# Epoch 29, Loss G: -0.0877, Loss D: 0.2058
# Epoch 30, Loss G: -0.0681, Loss D: 0.1572
# Epoch 31, Loss G: -0.3445, Loss D: 0.1787
# Epoch 32, Loss G: -0.2441, Loss D: 0.2903
# Epoch 33, Loss G: -0.3226, Loss D: 0.3077
# Epoch 34, Loss G: -0.3671, Loss D: 0.1951
# Epoch 35, Loss G: -0.2428, Loss D: 0.1255
# Epoch 36, Loss G: -0.2559, Loss D: 0.0819
# Epoch 37, Loss G: -0.2433, Loss D: -0.0182
# Epoch 38, Loss G: -0.4088, Loss D: -0.0931
# Epoch 39, Loss G: -0.4652, Loss D: -0.0450
# Epoch 40, Loss G: -0.4137, Loss D: -0.0833
# Epoch 41, Loss G: -0.4812, Loss D: -0.0218
# Epoch 42, Loss G: -0.4850, Loss D: -0.0713
# Epoch 43, Loss G: -0.5309, Loss D: -0.0656
# Epoch 44, Loss G: -0.5289, Loss D: -0.0259
# Epoch 45, Loss G: -0.5987, Loss D: -0.1010
# Epoch 46, Loss G: -0.6368, Loss D: 0.0781
# Epoch 47, Loss G: -0.7321, Loss D: 0.0496
# Epoch 48, Loss G: -0.7388, Loss D: 0.0530
# Epoch 49, Loss G: -0.8252, Loss D: 0.0783
# Epoch 50, Loss G: -0.8889, Loss D: 0.0446
# Epoch 51, Loss G: -0.7976, Loss D: 0.0636
# Epoch 52, Loss G: -0.7865, Loss D: 0.1036
# Epoch 53, Loss G: -0.7100, Loss D: 0.0346
# Epoch 54, Loss G: -0.7147, Loss D: 0.0040
# Epoch 55, Loss G: -0.8327, Loss D: 0.1144
# Epoch 56, Loss G: -0.7733, Loss D: 0.1599
# Epoch 57, Loss G: -0.8177, Loss D: 0.1578
# Epoch 58, Loss G: -0.9502, Loss D: 0.1319
# Epoch 59, Loss G: -0.8331, Loss D: 0.0316
# Epoch 60, Loss G: -0.7350, Loss D: -0.0304
# Epoch 61, Loss G: -0.8763, Loss D: -0.1098
# Epoch 62, Loss G: -0.8163, Loss D: -0.1236
# Epoch 63, Loss G: -0.6825, Loss D: -0.1162
# Epoch 64, Loss G: -0.8502, Loss D: 0.0255
# Epoch 65, Loss G: -0.8853, Loss D: 0.1500
# Epoch 66, Loss G: -1.0467, Loss D: -0.0298
# Epoch 67, Loss G: -1.0935, Loss D: 0.0893
# Epoch 68, Loss G: -1.0011, Loss D: 0.1185
# Epoch 69, Loss G: -1.0452, Loss D: 0.1875
# Epoch 70, Loss G: -0.9860, Loss D: 0.0213
# Epoch 71, Loss G: -0.9438, Loss D: -0.1512
# Epoch 72, Loss G: -1.0224, Loss D: -0.0909
# Epoch 73, Loss G: -0.9650, Loss D: -0.1275
# Epoch 74, Loss G: -1.0783, Loss D: -0.0898
# Epoch 75, Loss G: -1.1120, Loss D: 0.1656
# Epoch 76, Loss G: -1.2272, Loss D: 0.0522
# Epoch 77, Loss G: -1.1284, Loss D: 0.0401
# Epoch 78, Loss G: -1.1831, Loss D: 0.0004
# Epoch 79, Loss G: -1.1028, Loss D: 0.0402
# Epoch 80, Loss G: -1.0265, Loss D: 0.0247
# Epoch 81, Loss G: -1.0989, Loss D: -0.0694
# Epoch 82, Loss G: -1.0801, Loss D: 0.0952
# Epoch 83, Loss G: -1.1587, Loss D: 0.0995
# Epoch 84, Loss G: -1.2793, Loss D: 0.1162
# Epoch 85, Loss G: -1.2129, Loss D: 0.0547
# Epoch 86, Loss G: -1.1617, Loss D: -0.0808
# Epoch 87, Loss G: -1.1041, Loss D: -0.0902
# Epoch 88, Loss G: -1.0911, Loss D: -0.0169
# Epoch 89, Loss G: -1.0582, Loss D: -0.0792
# Epoch 90, Loss G: -1.0472, Loss D: 0.0142
# Epoch 91, Loss G: -0.9744, Loss D: 0.0214
# Epoch 92, Loss G: -1.0331, Loss D: -0.0391
# Epoch 93, Loss G: -1.1129, Loss D: -0.0293
# Epoch 94, Loss G: -1.0351, Loss D: -0.0310
# Epoch 95, Loss G: -0.9684, Loss D: -0.0884
# Epoch 96, Loss G: -0.9414, Loss D: -0.1598
# Epoch 97, Loss G: -1.0431, Loss D: -0.1111
# Epoch 98, Loss G: -1.0124, Loss D: 0.0956
# Epoch 99, Loss G: -1.3439, Loss D: 0.0736
# Epoch 100, Loss G: -1.2679, Loss D: 0.1300
# Epoch 101, Loss G: -1.2701, Loss D: 0.0514
# Epoch 102, Loss G: -1.2041, Loss D: 0.1617
# Epoch 103, Loss G: -1.1871, Loss D: -0.0745
# Epoch 104, Loss G: -1.2039, Loss D: -0.1020
# Epoch 105, Loss G: -1.3136, Loss D: -0.1425
# Epoch 106, Loss G: -1.3320, Loss D: 0.0809
# Epoch 107, Loss G: -1.2426, Loss D: -0.0125
# Epoch 108, Loss G: -1.2120, Loss D: -0.0564
# Epoch 109, Loss G: -1.1742, Loss D: -0.1214
# Epoch 110, Loss G: -1.2210, Loss D: -0.0610
# Epoch 111, Loss G: -1.2661, Loss D: 0.0541
# Epoch 112, Loss G: -1.4408, Loss D: -0.0953
# Epoch 113, Loss G: -1.4987, Loss D: 0.0356
# Epoch 114, Loss G: -1.5055, Loss D: 0.1628
# Epoch 115, Loss G: -1.4375, Loss D: 0.0345
# Epoch 116, Loss G: -1.4220, Loss D: -0.0300
# Epoch 117, Loss G: -1.4592, Loss D: 0.0810
# Epoch 118, Loss G: -1.4986, Loss D: 0.0538
# Epoch 119, Loss G: -1.4339, Loss D: -0.0240
# Epoch 120, Loss G: -1.3828, Loss D: -0.0217
# Epoch 121, Loss G: -1.2735, Loss D: -0.0001
# Epoch 122, Loss G: -1.3935, Loss D: 0.0003
# Epoch 123, Loss G: -1.4010, Loss D: 0.0762
# Epoch 124, Loss G: -1.3679, Loss D: -0.0069
# Epoch 125, Loss G: -1.4334, Loss D: 0.0129
# Epoch 126, Loss G: -1.3791, Loss D: -0.0959
# Epoch 127, Loss G: -1.4035, Loss D: -0.0350
# Epoch 128, Loss G: -1.4114, Loss D: -0.0223
# Epoch 129, Loss G: -1.3479, Loss D: -0.1357
# Epoch 130, Loss G: -1.2906, Loss D: -0.1890
# Epoch 131, Loss G: -1.3421, Loss D: 0.0504
# Epoch 132, Loss G: -1.3691, Loss D: 0.1054
# Epoch 133, Loss G: -1.4804, Loss D: -0.0405
# Epoch 134, Loss G: -1.4712, Loss D: 0.0656
# Epoch 135, Loss G: -1.4250, Loss D: -0.1006
# Epoch 136, Loss G: -1.4474, Loss D: -0.0255
# Epoch 137, Loss G: -1.4390, Loss D: -0.1039
# Epoch 138, Loss G: -1.4628, Loss D: 0.0236
# Epoch 139, Loss G: -1.5156, Loss D: 0.0580
# Epoch 140, Loss G: -1.4615, Loss D: -0.0052
# Epoch 141, Loss G: -1.5387, Loss D: 0.0075
# Epoch 142, Loss G: -1.5316, Loss D: 0.0226
# Epoch 143, Loss G: -1.5142, Loss D: 0.0148
# Epoch 144, Loss G: -1.4289, Loss D: -0.0433
# Epoch 145, Loss G: -1.3410, Loss D: -0.0710
# Epoch 146, Loss G: -1.4926, Loss D: 0.0597
# Epoch 147, Loss G: -1.6321, Loss D: 0.1193
# Epoch 148, Loss G: -1.5834, Loss D: 0.1205
# Epoch 149, Loss G: -1.5657, Loss D: 0.0594
# Epoch 150, Loss G: -1.6486, Loss D: 0.0932
# Epoch 151, Loss G: -1.5533, Loss D: -0.0033
# Epoch 152, Loss G: -1.4454, Loss D: -0.1942
# Epoch 153, Loss G: -1.3421, Loss D: -0.1811
# Epoch 154, Loss G: -1.5003, Loss D: -0.1521
# Epoch 155, Loss G: -1.5037, Loss D: 0.0077
# Epoch 156, Loss G: -1.6031, Loss D: 0.0417
# Epoch 157, Loss G: -1.6410, Loss D: 0.1309
# Epoch 158, Loss G: -1.5799, Loss D: 0.0620
# Epoch 159, Loss G: -1.5686, Loss D: 0.1060
# Epoch 160, Loss G: -1.5267, Loss D: -0.1647
# Epoch 161, Loss G: -1.4907, Loss D: -0.0191
# Epoch 162, Loss G: -1.4970, Loss D: -0.0131
# Epoch 163, Loss G: -1.5882, Loss D: -0.1103
# Epoch 164, Loss G: -1.5665, Loss D: -0.0630
# Epoch 165, Loss G: -1.5797, Loss D: -0.0147
# Epoch 166, Loss G: -1.6612, Loss D: 0.0552
# Epoch 167, Loss G: -1.5726, Loss D: -0.0703
# Epoch 168, Loss G: -1.5895, Loss D: 0.0446
# Epoch 169, Loss G: -1.5716, Loss D: -0.0801
# Epoch 170, Loss G: -1.5424, Loss D: -0.1219
# Epoch 171, Loss G: -1.3838, Loss D: -0.1827
# Epoch 172, Loss G: -1.3884, Loss D: -0.0737
# Epoch 173, Loss G: -1.3861, Loss D: -0.0233
# Epoch 174, Loss G: -1.4397, Loss D: -0.1293
# Epoch 175, Loss G: -1.4960, Loss D: -0.0384
# Epoch 176, Loss G: -1.5926, Loss D: 0.0006
# Epoch 177, Loss G: -1.5996, Loss D: 0.0158
# Epoch 178, Loss G: -1.6551, Loss D: 0.1681
# Epoch 179, Loss G: -1.7227, Loss D: 0.1726
# Epoch 180, Loss G: -1.7362, Loss D: -0.1100
# Epoch 181, Loss G: -1.5841, Loss D: -0.0196
# Epoch 182, Loss G: -1.5913, Loss D: -0.0605
# Epoch 183, Loss G: -1.5136, Loss D: 0.0956
# Epoch 184, Loss G: -1.6213, Loss D: -0.0786
# Epoch 185, Loss G: -1.6409, Loss D: -0.0259
# Epoch 186, Loss G: -1.6157, Loss D: -0.0182
# Epoch 187, Loss G: -1.6912, Loss D: 0.0400
# Epoch 188, Loss G: -1.5547, Loss D: -0.0608
# Epoch 189, Loss G: -1.5198, Loss D: -0.1692
# Epoch 190, Loss G: -1.5343, Loss D: -0.1204
# Epoch 191, Loss G: -1.5425, Loss D: -0.2054
# Epoch 192, Loss G: -1.5014, Loss D: -0.0539
# Epoch 193, Loss G: -1.5424, Loss D: -0.0527
# Epoch 194, Loss G: -1.7296, Loss D: 0.1075
# Epoch 195, Loss G: -1.6393, Loss D: 0.1611
# Epoch 196, Loss G: -1.7074, Loss D: 0.0329
# Epoch 197, Loss G: -1.6424, Loss D: -0.0171
# Epoch 198, Loss G: -1.6024, Loss D: -0.0509
# Epoch 199, Loss G: -1.5135, Loss D: -0.1748
# Epoch 200, Loss G: -1.5257, Loss D: -0.2082
# Epoch 201, Loss G: -1.6137, Loss D: 0.0048
# Epoch 202, Loss G: -1.6437, Loss D: -0.0448
# Epoch 203, Loss G: -1.6447, Loss D: 0.0608
# Epoch 204, Loss G: -1.6502, Loss D: 0.0177
# Epoch 205, Loss G: -1.6306, Loss D: 0.0866
# Epoch 206, Loss G: -1.5364, Loss D: -0.1136
# Epoch 207, Loss G: -1.4493, Loss D: 0.0236
# Epoch 208, Loss G: -1.5654, Loss D: -0.1278
# Epoch 209, Loss G: -1.6659, Loss D: 0.0213
# Epoch 210, Loss G: -1.7196, Loss D: -0.0005
# Epoch 211, Loss G: -1.6304, Loss D: 0.1046
# Epoch 212, Loss G: -1.6275, Loss D: 0.0180
# Epoch 213, Loss G: -1.7130, Loss D: -0.0331
# Epoch 214, Loss G: -1.7768, Loss D: 0.0319
# Epoch 215, Loss G: -1.6516, Loss D: -0.1136
# Epoch 216, Loss G: -1.6066, Loss D: -0.0135
# Epoch 217, Loss G: -1.5723, Loss D: -0.0340
# Epoch 218, Loss G: -1.6363, Loss D: -0.1318
# Epoch 219, Loss G: -1.5919, Loss D: -0.0546
# Epoch 220, Loss G: -1.5701, Loss D: -0.0513
# Epoch 221, Loss G: -1.5838, Loss D: -0.0117
# Epoch 222, Loss G: -1.6279, Loss D: 0.0208
# Epoch 223, Loss G: -1.6962, Loss D: -0.0125
# Epoch 224, Loss G: -1.4699, Loss D: 0.0098
# Epoch 225, Loss G: -1.5058, Loss D: -0.2091
# Epoch 226, Loss G: -1.5581, Loss D: -0.1040
# Epoch 227, Loss G: -1.5702, Loss D: -0.0998
# Epoch 228, Loss G: -1.6343, Loss D: 0.0978
# Epoch 229, Loss G: -1.7327, Loss D: 0.0352
# Epoch 230, Loss G: -1.5998, Loss D: -0.0015
# Epoch 231, Loss G: -1.7190, Loss D: -0.1181
# Epoch 232, Loss G: -1.5819, Loss D: 0.0528
# Epoch 233, Loss G: -1.5806, Loss D: 0.0182
# Epoch 234, Loss G: -1.6869, Loss D: -0.0951
# Epoch 235, Loss G: -1.6039, Loss D: 0.0580
# Epoch 236, Loss G: -1.6690, Loss D: -0.1035
# Epoch 237, Loss G: -1.5915, Loss D: 0.0124
# Epoch 238, Loss G: -1.5694, Loss D: -0.1918
# Epoch 239, Loss G: -1.6400, Loss D: 0.0609
# Epoch 240, Loss G: -1.6891, Loss D: -0.0057
# Epoch 241, Loss G: -1.6180, Loss D: -0.0158
# Epoch 242, Loss G: -1.5673, Loss D: -0.0068
# Epoch 243, Loss G: -1.5860, Loss D: 0.0720
# Epoch 244, Loss G: -1.5444, Loss D: -0.0961
# Epoch 245, Loss G: -1.6255, Loss D: 0.0120
# Epoch 246, Loss G: -1.6445, Loss D: -0.0502
# Epoch 247, Loss G: -1.7921, Loss D: 0.0254
# Epoch 248, Loss G: -1.7606, Loss D: -0.0286
# Epoch 249, Loss G: -1.6151, Loss D: 0.0146
# Epoch 250, Loss G: -1.5722, Loss D: -0.1505
# Epoch 251, Loss G: -1.5020, Loss D: 0.0367
# Epoch 252, Loss G: -1.5669, Loss D: -0.0279
# Epoch 253, Loss G: -1.4796, Loss D: -0.0704
# Epoch 254, Loss G: -1.5166, Loss D: 0.0230
# Epoch 255, Loss G: -1.5575, Loss D: 0.0195
# Epoch 256, Loss G: -1.5054, Loss D: 0.0156
# Epoch 257, Loss G: -1.5927, Loss D: 0.0354
# Epoch 258, Loss G: -1.4515, Loss D: -0.0854
# Epoch 259, Loss G: -1.4242, Loss D: -0.1446
# Epoch 260, Loss G: -1.3420, Loss D: 0.1178
# Epoch 261, Loss G: -1.5134, Loss D: -0.0922
# Epoch 262, Loss G: -1.4119, Loss D: -0.0056
# Epoch 263, Loss G: -1.3634, Loss D: -0.0278
# Epoch 264, Loss G: -1.4022, Loss D: -0.1311
# Epoch 265, Loss G: -1.4138, Loss D: -0.0518
# Epoch 266, Loss G: -1.3614, Loss D: -0.0949
# Epoch 267, Loss G: -1.5092, Loss D: 0.0372
# Epoch 268, Loss G: -1.4964, Loss D: 0.1542
# Epoch 269, Loss G: -1.4186, Loss D: 0.1333
# Epoch 270, Loss G: -1.6037, Loss D: 0.0605
# Epoch 271, Loss G: -1.5488, Loss D: 0.1138
# Epoch 272, Loss G: -1.4868, Loss D: -0.0280
# Epoch 273, Loss G: -1.4727, Loss D: 0.0860
# Epoch 274, Loss G: -1.5701, Loss D: -0.1132
# Epoch 275, Loss G: -1.5555, Loss D: -0.0454
# Epoch 276, Loss G: -1.3980, Loss D: -0.1241
# Epoch 277, Loss G: -1.4626, Loss D: -0.1210
# Epoch 278, Loss G: -1.3979, Loss D: -0.2437
# Epoch 279, Loss G: -1.4062, Loss D: -0.0866
# Epoch 280, Loss G: -1.5217, Loss D: 0.1332
# Epoch 281, Loss G: -1.4811, Loss D: -0.0610
# Epoch 282, Loss G: -1.5145, Loss D: 0.0013
# Epoch 283, Loss G: -1.5979, Loss D: 0.0080
# Epoch 284, Loss G: -1.5968, Loss D: -0.0119
# Epoch 285, Loss G: -1.4785, Loss D: -0.0297
# Epoch 286, Loss G: -1.4600, Loss D: -0.0764
# Epoch 287, Loss G: -1.5926, Loss D: -0.0112
# Epoch 288, Loss G: -1.4193, Loss D: -0.0012
# Epoch 289, Loss G: -1.5164, Loss D: -0.0501
# Epoch 290, Loss G: -1.4348, Loss D: 0.0574
# Epoch 291, Loss G: -1.4221, Loss D: -0.0485
# Epoch 292, Loss G: -1.4682, Loss D: -0.1997
# Epoch 293, Loss G: -1.5423, Loss D: -0.0719
# Epoch 294, Loss G: -1.6596, Loss D: -0.0661
# Epoch 295, Loss G: -1.5438, Loss D: 0.0249
# Epoch 296, Loss G: -1.5663, Loss D: 0.1340
# Epoch 297, Loss G: -1.4555, Loss D: -0.1256
# Epoch 298, Loss G: -1.5312, Loss D: -0.0588
# Epoch 299, Loss G: -1.4537, Loss D: -0.0995
# Epoch 300, Loss G: -1.3771, Loss D: 0.0628

# %% [markdown]
# ## Cresh
# Required samples
#
# | Model | 9 | 10 | 11 |
# |---|---|---|---|
# | SMOTE | 547 | 0 | 433 |
# | ADASYN | 534 | 0 | 402 |

# %% [markdown]
# ## ASHRAE
# Required samples
#
# | Model  | -1 | 0 | 1 |
# |--------|----|----|----|
# | SMOTE  | 7686 | 0 | 3167 |
# | ADASYN | 8141 | 0 | 3167 |

# %%
discrete_columns_ashrae = [
    'Thermal sensation rounded'
]

ctgan_ashrae = CTGANSynthesizer()
ctgan_ashrae.fit(df_ashrae_train, discrete_columns_ashrae, epochs=600)
save_pickle(ctgan_ashrae, "models/ctgan_ashrae_reduced.pkl")
# Out:
# Epoch 1, Loss G: 0.1217, Loss D: 0.0285
# Epoch 2, Loss G: -0.7411, Loss D: 0.0209
# Epoch 3, Loss G: -1.0486, Loss D: 0.0388
# Epoch 4, Loss G: -1.1401, Loss D: -0.1162
# Epoch 5, Loss G: -1.5141, Loss D: -0.0441
# Epoch 6, Loss G: -1.5996, Loss D: 0.0939
# Epoch 7, Loss G: -1.5514, Loss D: 0.1002
# Epoch 8, Loss G: -1.7177, Loss D: 0.0008
# Epoch 9, Loss G: -1.7831, Loss D: 0.0494
# Epoch 10, Loss G: -1.6974, Loss D: 0.0592
# Epoch 11, Loss G: -1.9259, Loss D: 0.0212
# Epoch 12, Loss G: -1.8926, Loss D: 0.1224
# Epoch 13, Loss G: -1.8374, Loss D: 0.0117
# Epoch 14, Loss G: -1.9471, Loss D: 0.0417
# Epoch 15, Loss G: -1.9125, Loss D: -0.0217
# Epoch 16, Loss G: -2.0393, Loss D: 0.0414
# Epoch 17, Loss G: -1.9643, Loss D: -0.0942
# Epoch 18, Loss G: -1.9512, Loss D: -0.0174
# Epoch 19, Loss G: -2.1509, Loss D: 0.0011
# Epoch 20, Loss G: -1.9764, Loss D: 0.0960
# Epoch 21, Loss G: -2.0597, Loss D: -0.0974
# Epoch 22, Loss G: -2.0817, Loss D: -0.0156
# Epoch 23, Loss G: -2.0674, Loss D: -0.0135
# Epoch 24, Loss G: -2.0234, Loss D: 0.0530
# Epoch 25, Loss G: -1.9775, Loss D: -0.0344
# Epoch 26, Loss G: -2.1895, Loss D: -0.0248
# Epoch 27, Loss G: -2.2720, Loss D: 0.0409
# Epoch 28, Loss G: -2.2415, Loss D: -0.0714
# Epoch 29, Loss G: -2.1161, Loss D: -0.0996
# Epoch 30, Loss G: -2.2442, Loss D: -0.0401
# Epoch 31, Loss G: -2.2160, Loss D: 0.0508
# Epoch 32, Loss G: -2.2177, Loss D: -0.0275
# Epoch 33, Loss G: -2.1520, Loss D: 0.0784
# Epoch 34, Loss G: -2.1242, Loss D: -0.0032
# Epoch 35, Loss G: -2.2142, Loss D: -0.0297
# Epoch 36, Loss G: -2.1513, Loss D: -0.0338
# Epoch 37, Loss G: -2.2788, Loss D: 0.0208
# Epoch 38, Loss G: -2.1643, Loss D: 0.0017
# Epoch 39, Loss G: -2.2171, Loss D: 0.0141
# Epoch 40, Loss G: -2.1801, Loss D: -0.0060
# Epoch 41, Loss G: -2.1742, Loss D: 0.0660
# Epoch 42, Loss G: -2.1298, Loss D: -0.0144
# Epoch 43, Loss G: -2.2384, Loss D: -0.0399
# Epoch 44, Loss G: -2.2012, Loss D: -0.0228
# Epoch 45, Loss G: -2.2085, Loss D: 0.1342
# Epoch 46, Loss G: -2.1293, Loss D: 0.0958
# Epoch 47, Loss G: -2.1352, Loss D: 0.0663
# Epoch 48, Loss G: -2.1525, Loss D: 0.0395
# Epoch 49, Loss G: -2.2090, Loss D: -0.0308
# Epoch 50, Loss G: -2.1954, Loss D: 0.0147
# Epoch 51, Loss G: -2.2418, Loss D: -0.0560
# Epoch 52, Loss G: -2.2312, Loss D: -0.0969
# Epoch 53, Loss G: -2.1237, Loss D: -0.0789
# Epoch 54, Loss G: -2.1963, Loss D: 0.0545
# Epoch 55, Loss G: -2.1584, Loss D: 0.0787
# Epoch 56, Loss G: -2.2622, Loss D: -0.0365
# Epoch 57, Loss G: -2.1217, Loss D: -0.0512
# Epoch 58, Loss G: -2.2039, Loss D: -0.0236
# Epoch 59, Loss G: -2.2372, Loss D: 0.0155
# Epoch 60, Loss G: -2.2162, Loss D: 0.0196
# Epoch 61, Loss G: -2.1137, Loss D: 0.0198
# Epoch 62, Loss G: -2.1578, Loss D: 0.0110
# Epoch 63, Loss G: -2.1699, Loss D: -0.0458
# Epoch 64, Loss G: -2.1775, Loss D: -0.0145
# Epoch 65, Loss G: -2.1019, Loss D: -0.0310
# Epoch 66, Loss G: -2.1587, Loss D: 0.0007
# Epoch 67, Loss G: -2.1352, Loss D: -0.0551
# Epoch 68, Loss G: -2.1690, Loss D: -0.0583
# Epoch 69, Loss G: -2.1451, Loss D: -0.0255
# Epoch 70, Loss G: -2.2172, Loss D: 0.0086
# Epoch 71, Loss G: -2.1823, Loss D: 0.0226
# Epoch 72, Loss G: -2.1197, Loss D: -0.0737
# Epoch 73, Loss G: -2.2406, Loss D: 0.1133
# Epoch 74, Loss G: -2.1508, Loss D: 0.0154
# Epoch 75, Loss G: -2.1818, Loss D: -0.0197
# Epoch 76, Loss G: -2.1942, Loss D: 0.0283
# Epoch 77, Loss G: -2.2598, Loss D: 0.0310
# Epoch 78, Loss G: -2.1146, Loss D: -0.0486
# Epoch 79, Loss G: -2.2271, Loss D: -0.0274
# Epoch 80, Loss G: -2.1795, Loss D: -0.0774
# Epoch 81, Loss G: -2.2702, Loss D: 0.0199
# Epoch 82, Loss G: -2.1012, Loss D: 0.0182
# Epoch 83, Loss G: -2.2256, Loss D: -0.0127
# Epoch 84, Loss G: -2.1618, Loss D: -0.0076
# Epoch 85, Loss G: -2.2209, Loss D: 0.0123
# Epoch 86, Loss G: -2.1872, Loss D: -0.0702
# Epoch 87, Loss G: -2.1416, Loss D: -0.0202
# Epoch 88, Loss G: -2.1976, Loss D: 0.0025
# Epoch 89, Loss G: -2.2461, Loss D: 0.0259
# Epoch 90, Loss G: -2.1740, Loss D: 0.0085
# Epoch 91, Loss G: -2.2314, Loss D: 0.0077
# Epoch 92, Loss G: -2.2469, Loss D: -0.0692
# Epoch 93, Loss G: -2.1975, Loss D: -0.0043
# Epoch 94, Loss G: -2.1589, Loss D: -0.0865
# Epoch 95, Loss G: -2.1989, Loss D: 0.0462
# Epoch 96, Loss G: -2.1958, Loss D: -0.0714
# Epoch 97, Loss G: -2.1995, Loss D: -0.0094
# Epoch 98, Loss G: -2.2014, Loss D: -0.0306
# Epoch 99, Loss G: -2.1637, Loss D: 0.0451
# Epoch 100, Loss G: -2.1942, Loss D: -0.0029
# Epoch 101, Loss G: -2.1673, Loss D: -0.0090
# Epoch 102, Loss G: -2.2141, Loss D: -0.0775
# Epoch 103, Loss G: -2.2178, Loss D: 0.0207
# Epoch 104, Loss G: -2.1338, Loss D: 0.0407
# Epoch 105, Loss G: -2.2631, Loss D: -0.0497
# Epoch 106, Loss G: -2.0849, Loss D: 0.0098
# Epoch 107, Loss G: -2.2276, Loss D: 0.0505
# Epoch 108, Loss G: -2.2147, Loss D: -0.0790
# Epoch 109, Loss G: -2.1768, Loss D: -0.0277
# Epoch 110, Loss G: -2.1807, Loss D: 0.0312
# Epoch 111, Loss G: -2.1452, Loss D: -0.0394
# Epoch 112, Loss G: -2.1297, Loss D: 0.0106
# Epoch 113, Loss G: -2.2698, Loss D: -0.0770
# Epoch 114, Loss G: -2.2785, Loss D: -0.0362
# Epoch 115, Loss G: -2.1533, Loss D: 0.0393
# Epoch 116, Loss G: -2.2669, Loss D: 0.0058
# Epoch 117, Loss G: -2.2364, Loss D: -0.0059
# Epoch 118, Loss G: -2.2370, Loss D: -0.0528
# Epoch 119, Loss G: -2.2336, Loss D: -0.0482
# Epoch 120, Loss G: -2.2442, Loss D: -0.0320
# Epoch 121, Loss G: -2.2579, Loss D: -0.0339
# Epoch 122, Loss G: -2.2022, Loss D: 0.0252
# Epoch 123, Loss G: -2.2984, Loss D: -0.0004
# Epoch 124, Loss G: -2.3214, Loss D: -0.0456
# Epoch 125, Loss G: -2.2403, Loss D: -0.0479
# Epoch 126, Loss G: -2.1838, Loss D: 0.0220
# Epoch 127, Loss G: -2.2418, Loss D: -0.0473
# Epoch 128, Loss G: -2.1984, Loss D: 0.0324
# Epoch 129, Loss G: -2.3652, Loss D: -0.0069
# Epoch 130, Loss G: -2.1992, Loss D: -0.0125
# Epoch 131, Loss G: -2.2900, Loss D: 0.0169
# Epoch 132, Loss G: -2.2159, Loss D: 0.0072
# Epoch 133, Loss G: -2.2293, Loss D: -0.0019
# Epoch 134, Loss G: -2.2398, Loss D: 0.0295
# Epoch 135, Loss G: -2.3317, Loss D: -0.0677
# Epoch 136, Loss G: -2.2629, Loss D: -0.0424
# Epoch 137, Loss G: -2.1625, Loss D: -0.1205
# Epoch 138, Loss G: -2.2332, Loss D: -0.0260
# Epoch 139, Loss G: -2.2382, Loss D: 0.0850
# Epoch 140, Loss G: -2.2182, Loss D: 0.0153
# Epoch 141, Loss G: -2.2685, Loss D: 0.0472
# Epoch 142, Loss G: -2.2225, Loss D: 0.0171
# Epoch 143, Loss G: -2.3157, Loss D: 0.0607
# Epoch 144, Loss G: -2.1147, Loss D: 0.0283
# Epoch 145, Loss G: -2.3173, Loss D: -0.0038
# Epoch 146, Loss G: -2.2230, Loss D: -0.0125
# Epoch 147, Loss G: -2.2150, Loss D: -0.0820
# Epoch 148, Loss G: -2.1941, Loss D: 0.0574
# Epoch 149, Loss G: -2.1702, Loss D: -0.0243
# Epoch 150, Loss G: -2.3149, Loss D: 0.1240
# Epoch 151, Loss G: -2.2681, Loss D: 0.0162
# Epoch 152, Loss G: -2.2345, Loss D: -0.0569
# Epoch 153, Loss G: -2.3282, Loss D: 0.0272
# Epoch 154, Loss G: -2.2899, Loss D: -0.0069
# Epoch 155, Loss G: -2.1541, Loss D: 0.0270
# Epoch 156, Loss G: -2.2923, Loss D: -0.0087
# Epoch 157, Loss G: -2.1271, Loss D: 0.0408
# Epoch 158, Loss G: -2.2797, Loss D: 0.0205
# Epoch 159, Loss G: -2.2341, Loss D: 0.0134
# Epoch 160, Loss G: -2.1961, Loss D: 0.0450
# Epoch 161, Loss G: -2.3247, Loss D: 0.0537
# Epoch 162, Loss G: -2.2646, Loss D: 0.0125
# Epoch 163, Loss G: -2.1968, Loss D: 0.0023
# Epoch 164, Loss G: -2.2772, Loss D: -0.0078
# Epoch 165, Loss G: -2.2593, Loss D: 0.0424
# Epoch 166, Loss G: -2.1698, Loss D: -0.0322
# Epoch 167, Loss G: -2.2490, Loss D: -0.0900
# Epoch 168, Loss G: -2.2226, Loss D: 0.0356
# Epoch 169, Loss G: -2.2577, Loss D: 0.0341
# Epoch 170, Loss G: -2.3280, Loss D: -0.0680
# Epoch 171, Loss G: -2.2599, Loss D: 0.0737
# Epoch 172, Loss G: -2.1954, Loss D: 0.0176
# Epoch 173, Loss G: -2.1651, Loss D: -0.1041
# Epoch 174, Loss G: -2.2211, Loss D: 0.0062
# Epoch 175, Loss G: -2.1288, Loss D: 0.0568
# Epoch 176, Loss G: -2.2430, Loss D: -0.0378
# Epoch 177, Loss G: -2.2573, Loss D: -0.0780
# Epoch 178, Loss G: -2.2039, Loss D: -0.0079
# Epoch 179, Loss G: -2.2642, Loss D: 0.0104
# Epoch 180, Loss G: -2.2290, Loss D: -0.0276
# Epoch 181, Loss G: -2.2747, Loss D: -0.0563
# Epoch 182, Loss G: -2.2741, Loss D: 0.0024
# Epoch 183, Loss G: -2.2182, Loss D: 0.0009
# Epoch 184, Loss G: -2.1978, Loss D: -0.0014
# Epoch 185, Loss G: -2.2053, Loss D: -0.0308
# Epoch 186, Loss G: -2.1643, Loss D: -0.0874
# Epoch 187, Loss G: -2.1704, Loss D: 0.0416
# Epoch 188, Loss G: -2.3342, Loss D: 0.0622
# Epoch 189, Loss G: -2.1271, Loss D: 0.0619
# Epoch 190, Loss G: -2.2068, Loss D: -0.0009
# Epoch 191, Loss G: -2.2552, Loss D: -0.0424
# Epoch 192, Loss G: -2.2071, Loss D: 0.1500
# Epoch 193, Loss G: -2.2726, Loss D: -0.0103
# Epoch 194, Loss G: -2.2878, Loss D: 0.0105
# Epoch 195, Loss G: -2.1748, Loss D: -0.0547
# Epoch 196, Loss G: -2.3425, Loss D: 0.0125
# Epoch 197, Loss G: -2.1654, Loss D: 0.0409
# Epoch 198, Loss G: -2.1816, Loss D: 0.0199
# Epoch 199, Loss G: -2.2708, Loss D: -0.0390
# Epoch 200, Loss G: -2.3023, Loss D: 0.0565
# Epoch 201, Loss G: -2.2101, Loss D: -0.0243
# Epoch 202, Loss G: -2.2959, Loss D: 0.0437
# Epoch 203, Loss G: -2.2176, Loss D: -0.0067
# Epoch 204, Loss G: -2.2199, Loss D: -0.0762
# Epoch 205, Loss G: -2.1616, Loss D: -0.0194
# Epoch 206, Loss G: -2.2962, Loss D: -0.0474
# Epoch 207, Loss G: -2.2179, Loss D: -0.0414
# Epoch 208, Loss G: -2.2870, Loss D: -0.0756
# Epoch 209, Loss G: -2.1221, Loss D: -0.0472
# Epoch 210, Loss G: -2.2533, Loss D: -0.0940
# Epoch 211, Loss G: -2.2180, Loss D: 0.0003
# Epoch 212, Loss G: -2.2694, Loss D: -0.0108
# Epoch 213, Loss G: -2.1394, Loss D: 0.0123
# Epoch 214, Loss G: -2.2234, Loss D: 0.0149
# Epoch 215, Loss G: -2.3740, Loss D: 0.0293
# Epoch 216, Loss G: -2.1720, Loss D: 0.0903
# Epoch 217, Loss G: -2.2112, Loss D: 0.0125
# Epoch 218, Loss G: -2.2808, Loss D: 0.0176
# Epoch 219, Loss G: -2.2992, Loss D: 0.0142
# Epoch 220, Loss G: -2.2295, Loss D: 0.0179
# Epoch 221, Loss G: -2.0896, Loss D: -0.0399
# Epoch 222, Loss G: -2.1715, Loss D: 0.0431
# Epoch 223, Loss G: -2.2169, Loss D: 0.0271
# Epoch 224, Loss G: -2.3121, Loss D: -0.0299
# Epoch 225, Loss G: -2.1383, Loss D: 0.0197
# Epoch 226, Loss G: -2.1950, Loss D: 0.0930
# Epoch 227, Loss G: -2.2210, Loss D: -0.0161
# Epoch 228, Loss G: -2.2553, Loss D: -0.0236
# Epoch 229, Loss G: -2.2886, Loss D: -0.0288
# Epoch 230, Loss G: -2.1716, Loss D: 0.0587
# Epoch 231, Loss G: -2.2248, Loss D: 0.0022
# Epoch 232, Loss G: -2.2434, Loss D: -0.0271
# Epoch 233, Loss G: -2.2080, Loss D: -0.0127
# Epoch 234, Loss G: -2.3128, Loss D: -0.0344
# Epoch 235, Loss G: -2.1363, Loss D: 0.0455
# Epoch 236, Loss G: -2.2970, Loss D: -0.0045
# Epoch 237, Loss G: -2.2535, Loss D: -0.0052
# Epoch 238, Loss G: -2.3272, Loss D: -0.0766
# Epoch 239, Loss G: -2.2945, Loss D: -0.0213
# Epoch 240, Loss G: -2.3364, Loss D: -0.0782
# Epoch 241, Loss G: -2.2701, Loss D: 0.0620
# Epoch 242, Loss G: -2.2356, Loss D: -0.0283
# Epoch 243, Loss G: -2.2138, Loss D: 0.0124
# Epoch 244, Loss G: -2.2285, Loss D: 0.0602
# Epoch 245, Loss G: -2.2845, Loss D: -0.0388
# Epoch 246, Loss G: -2.1839, Loss D: 0.0216
# Epoch 247, Loss G: -2.2838, Loss D: 0.0311
# Epoch 248, Loss G: -2.2405, Loss D: -0.0419
# Epoch 249, Loss G: -2.2530, Loss D: 0.0084
# Epoch 250, Loss G: -2.2772, Loss D: 0.0214
# Epoch 251, Loss G: -2.3426, Loss D: -0.1383
# Epoch 252, Loss G: -2.2495, Loss D: -0.0301
# Epoch 253, Loss G: -2.2056, Loss D: 0.0738
# Epoch 254, Loss G: -2.3021, Loss D: -0.0093
# Epoch 255, Loss G: -2.2895, Loss D: 0.0741
# Epoch 256, Loss G: -2.2421, Loss D: -0.0421
# Epoch 257, Loss G: -2.2300, Loss D: -0.0016
# Epoch 258, Loss G: -2.1587, Loss D: -0.0407
# Epoch 259, Loss G: -2.1833, Loss D: 0.0297
# Epoch 260, Loss G: -2.3787, Loss D: -0.0541
# Epoch 261, Loss G: -2.1698, Loss D: 0.0848
# Epoch 262, Loss G: -2.2321, Loss D: -0.0769
# Epoch 263, Loss G: -2.2827, Loss D: 0.0360
# Epoch 264, Loss G: -2.2538, Loss D: 0.0210
# Epoch 265, Loss G: -2.2127, Loss D: -0.0100
# Epoch 266, Loss G: -2.1588, Loss D: -0.0538
# Epoch 267, Loss G: -2.3049, Loss D: 0.0397
# Epoch 268, Loss G: -2.1378, Loss D: -0.0328
# Epoch 269, Loss G: -2.2592, Loss D: -0.0223
# Epoch 270, Loss G: -2.2507, Loss D: -0.0313
# Epoch 271, Loss G: -2.2150, Loss D: -0.0638
# Epoch 272, Loss G: -2.2000, Loss D: -0.0512
# Epoch 273, Loss G: -2.2081, Loss D: 0.0006
# Epoch 274, Loss G: -2.3374, Loss D: -0.1094
# Epoch 275, Loss G: -2.1622, Loss D: -0.0365
# Epoch 276, Loss G: -2.2600, Loss D: -0.0108
# Epoch 277, Loss G: -2.2934, Loss D: 0.0161
# Epoch 278, Loss G: -2.3259, Loss D: 0.0268
# Epoch 279, Loss G: -2.2753, Loss D: -0.1704
# Epoch 280, Loss G: -2.2593, Loss D: 0.0278
# Epoch 281, Loss G: -2.2219, Loss D: 0.0399
# Epoch 282, Loss G: -2.2407, Loss D: -0.0194
# Epoch 283, Loss G: -2.2089, Loss D: -0.1054
# Epoch 284, Loss G: -2.2040, Loss D: 0.0369
# Epoch 285, Loss G: -2.2891, Loss D: 0.0648
# Epoch 286, Loss G: -2.2612, Loss D: 0.0298
# Epoch 287, Loss G: -2.2672, Loss D: 0.0609
# Epoch 288, Loss G: -2.2659, Loss D: 0.0223
# Epoch 289, Loss G: -2.2434, Loss D: 0.0784
# Epoch 290, Loss G: -2.1921, Loss D: 0.0106
# Epoch 291, Loss G: -2.1470, Loss D: -0.0683
# Epoch 292, Loss G: -2.1397, Loss D: -0.1238
# Epoch 293, Loss G: -2.1602, Loss D: 0.0388
# Epoch 294, Loss G: -2.3064, Loss D: -0.0425
# Epoch 295, Loss G: -2.1999, Loss D: -0.0038
# Epoch 296, Loss G: -2.2426, Loss D: -0.0338
# Epoch 297, Loss G: -2.2555, Loss D: 0.0132
# Epoch 298, Loss G: -2.2963, Loss D: 0.0043
# Epoch 299, Loss G: -2.2393, Loss D: 0.0235
# Epoch 300, Loss G: -2.2488, Loss D: 0.0173
# Epoch 301, Loss G: -2.1299, Loss D: -0.0814
# Epoch 302, Loss G: -2.2488, Loss D: 0.0431
# Epoch 303, Loss G: -2.2347, Loss D: 0.0028
# Epoch 304, Loss G: -2.2635, Loss D: -0.0664
# Epoch 305, Loss G: -2.2486, Loss D: -0.0021
# Epoch 306, Loss G: -2.3001, Loss D: -0.0249
# Epoch 307, Loss G: -2.2149, Loss D: 0.0308
# Epoch 308, Loss G: -2.1380, Loss D: -0.0062
# Epoch 309, Loss G: -2.3094, Loss D: -0.0429
# Epoch 310, Loss G: -2.2951, Loss D: -0.1131
# Epoch 311, Loss G: -2.2289, Loss D: -0.0708
# Epoch 312, Loss G: -2.2452, Loss D: 0.0346
# Epoch 313, Loss G: -2.2885, Loss D: -0.0021
# Epoch 314, Loss G: -2.3269, Loss D: -0.0229
# Epoch 315, Loss G: -2.3081, Loss D: -0.0448
# Epoch 316, Loss G: -2.2654, Loss D: 0.0388
# Epoch 317, Loss G: -2.3973, Loss D: -0.0537
# Epoch 318, Loss G: -2.3071, Loss D: -0.0468
# Epoch 319, Loss G: -2.4179, Loss D: -0.0675
# Epoch 320, Loss G: -2.2052, Loss D: -0.0216
# Epoch 321, Loss G: -2.2049, Loss D: 0.0471
# Epoch 322, Loss G: -2.2938, Loss D: 0.0511
# Epoch 323, Loss G: -2.2872, Loss D: -0.0505
# Epoch 324, Loss G: -2.2327, Loss D: 0.0211
# Epoch 325, Loss G: -2.1551, Loss D: 0.0626
# Epoch 326, Loss G: -2.2500, Loss D: 0.0285
# Epoch 327, Loss G: -2.2984, Loss D: 0.0085
# Epoch 328, Loss G: -2.2523, Loss D: 0.1036
# Epoch 329, Loss G: -2.3479, Loss D: -0.0857
# Epoch 330, Loss G: -2.1542, Loss D: -0.0283
# Epoch 331, Loss G: -2.3862, Loss D: 0.0384
# Epoch 332, Loss G: -2.2933, Loss D: 0.0223
# Epoch 333, Loss G: -2.2766, Loss D: 0.0446
# Epoch 334, Loss G: -2.3128, Loss D: -0.0135
# Epoch 335, Loss G: -2.2029, Loss D: 0.0560
# Epoch 336, Loss G: -2.2088, Loss D: 0.0048
# Epoch 337, Loss G: -2.3017, Loss D: 0.0088
# Epoch 338, Loss G: -2.4021, Loss D: 0.0624
# Epoch 339, Loss G: -2.2263, Loss D: -0.0748
# Epoch 340, Loss G: -2.2199, Loss D: 0.0447
# Epoch 341, Loss G: -2.2890, Loss D: -0.0302
# Epoch 342, Loss G: -2.2409, Loss D: -0.0495
# Epoch 343, Loss G: -2.1473, Loss D: 0.0170
# Epoch 344, Loss G: -2.3179, Loss D: -0.0637
# Epoch 345, Loss G: -2.1719, Loss D: -0.0338
# Epoch 346, Loss G: -2.3784, Loss D: -0.0007
# Epoch 347, Loss G: -2.2521, Loss D: -0.0282
# Epoch 348, Loss G: -2.2595, Loss D: -0.1603
# Epoch 349, Loss G: -2.3477, Loss D: -0.0423
# Epoch 350, Loss G: -2.2752, Loss D: 0.1245
# Epoch 351, Loss G: -2.2840, Loss D: -0.0575
# Epoch 352, Loss G: -2.3683, Loss D: 0.0479
# Epoch 353, Loss G: -2.2904, Loss D: -0.0038
# Epoch 354, Loss G: -2.3595, Loss D: 0.0018
# Epoch 355, Loss G: -2.2222, Loss D: -0.0495
# Epoch 356, Loss G: -2.3041, Loss D: -0.0430
# Epoch 357, Loss G: -2.2595, Loss D: 0.0457
# Epoch 358, Loss G: -2.2167, Loss D: -0.0055
# Epoch 359, Loss G: -2.2456, Loss D: 0.0614
# Epoch 360, Loss G: -2.3354, Loss D: 0.0997
# Epoch 361, Loss G: -2.2872, Loss D: -0.0245
# Epoch 362, Loss G: -2.2338, Loss D: -0.0311
# Epoch 363, Loss G: -2.2462, Loss D: -0.0314
# Epoch 364, Loss G: -2.1885, Loss D: 0.0422
# Epoch 365, Loss G: -2.1900, Loss D: -0.0559
# Epoch 366, Loss G: -2.3397, Loss D: -0.0228
# Epoch 367, Loss G: -2.2441, Loss D: -0.0227
# Epoch 368, Loss G: -2.1771, Loss D: 0.0143
# Epoch 369, Loss G: -2.3050, Loss D: 0.0441
# Epoch 370, Loss G: -2.2216, Loss D: 0.0071
# Epoch 371, Loss G: -2.1413, Loss D: 0.0337
# Epoch 372, Loss G: -2.2571, Loss D: -0.0090
# Epoch 373, Loss G: -2.3468, Loss D: 0.0899
# Epoch 374, Loss G: -2.3239, Loss D: -0.0831
# Epoch 375, Loss G: -2.3182, Loss D: -0.0452
# Epoch 376, Loss G: -2.1384, Loss D: 0.0029
# Epoch 377, Loss G: -2.2617, Loss D: -0.0164
# Epoch 378, Loss G: -2.4062, Loss D: 0.0141
# Epoch 379, Loss G: -2.2339, Loss D: 0.0139
# Epoch 380, Loss G: -2.2160, Loss D: -0.0500
# Epoch 381, Loss G: -2.2950, Loss D: -0.0291
# Epoch 382, Loss G: -2.2007, Loss D: 0.0792
# Epoch 383, Loss G: -2.2373, Loss D: 0.1672
# Epoch 384, Loss G: -2.2385, Loss D: -0.0125
# Epoch 385, Loss G: -2.3461, Loss D: -0.0584
# Epoch 386, Loss G: -2.1990, Loss D: 0.0279
# Epoch 387, Loss G: -2.2637, Loss D: -0.0780
# Epoch 388, Loss G: -2.3537, Loss D: 0.0194
# Epoch 389, Loss G: -2.3536, Loss D: -0.0146
# Epoch 390, Loss G: -2.2070, Loss D: -0.0243
# Epoch 391, Loss G: -2.2412, Loss D: -0.0048
# Epoch 392, Loss G: -2.1756, Loss D: 0.0370
# Epoch 393, Loss G: -2.2419, Loss D: 0.0060
# Epoch 394, Loss G: -2.2964, Loss D: 0.0103
# Epoch 395, Loss G: -2.2424, Loss D: -0.0555
# Epoch 396, Loss G: -2.2424, Loss D: 0.0190
# Epoch 397, Loss G: -2.1929, Loss D: 0.0384
# Epoch 398, Loss G: -2.2684, Loss D: -0.0503
# Epoch 399, Loss G: -2.2456, Loss D: -0.0047
# Epoch 400, Loss G: -2.2689, Loss D: -0.0370
# Epoch 401, Loss G: -2.2821, Loss D: 0.0354
# Epoch 402, Loss G: -2.3625, Loss D: 0.0949
# Epoch 403, Loss G: -2.2546, Loss D: 0.0124
# Epoch 404, Loss G: -2.3537, Loss D: -0.0051
# Epoch 405, Loss G: -2.3094, Loss D: 0.0024
# Epoch 406, Loss G: -2.2909, Loss D: 0.0402
# Epoch 407, Loss G: -2.2142, Loss D: -0.0277
# Epoch 408, Loss G: -2.2418, Loss D: 0.0452
# Epoch 409, Loss G: -2.2635, Loss D: -0.0029
# Epoch 410, Loss G: -2.3025, Loss D: -0.0945
# Epoch 411, Loss G: -2.3631, Loss D: -0.0090
# Epoch 412, Loss G: -2.3934, Loss D: -0.0208
# Epoch 413, Loss G: -2.2736, Loss D: -0.0103
# Epoch 414, Loss G: -2.2051, Loss D: -0.0062
# Epoch 415, Loss G: -2.4072, Loss D: -0.0148
# Epoch 416, Loss G: -2.2008, Loss D: 0.1800
# Epoch 417, Loss G: -2.2906, Loss D: 0.0338
# Epoch 418, Loss G: -2.3251, Loss D: -0.0711
# Epoch 419, Loss G: -2.1735, Loss D: 0.0049
# Epoch 420, Loss G: -2.2502, Loss D: -0.0163
# Epoch 421, Loss G: -2.2340, Loss D: 0.0391
# Epoch 422, Loss G: -2.2063, Loss D: 0.0965
# Epoch 423, Loss G: -2.3305, Loss D: -0.0121
# Epoch 424, Loss G: -2.2578, Loss D: 0.0183
# Epoch 425, Loss G: -2.3572, Loss D: -0.0068
# Epoch 426, Loss G: -2.3131, Loss D: -0.0252
# Epoch 427, Loss G: -2.3369, Loss D: -0.0768
# Epoch 428, Loss G: -2.2797, Loss D: -0.0660
# Epoch 429, Loss G: -2.3649, Loss D: -0.0530
# Epoch 430, Loss G: -2.2177, Loss D: -0.0410
# Epoch 431, Loss G: -2.1643, Loss D: 0.0597
# Epoch 432, Loss G: -2.2983, Loss D: -0.0279
# Epoch 433, Loss G: -2.3152, Loss D: -0.0876
# Epoch 434, Loss G: -2.3086, Loss D: -0.1079
# Epoch 435, Loss G: -2.2841, Loss D: -0.0851
# Epoch 436, Loss G: -2.2670, Loss D: 0.0301
# Epoch 437, Loss G: -2.3439, Loss D: -0.0750
# Epoch 438, Loss G: -2.2795, Loss D: -0.0773
# Epoch 439, Loss G: -2.3082, Loss D: -0.0539
# Epoch 440, Loss G: -2.3099, Loss D: -0.0236
# Epoch 441, Loss G: -2.2174, Loss D: -0.0408
# Epoch 442, Loss G: -2.1593, Loss D: 0.0019
# Epoch 443, Loss G: -2.2447, Loss D: 0.0130
# Epoch 444, Loss G: -2.2422, Loss D: 0.0043
# Epoch 445, Loss G: -2.2544, Loss D: -0.0874
# Epoch 446, Loss G: -2.3113, Loss D: 0.0304
# Epoch 447, Loss G: -2.2241, Loss D: -0.0548
# Epoch 448, Loss G: -2.2451, Loss D: -0.1230
# Epoch 449, Loss G: -2.3092, Loss D: -0.0266
# Epoch 450, Loss G: -2.3740, Loss D: -0.0731
# Epoch 451, Loss G: -2.3598, Loss D: 0.0229
# Epoch 452, Loss G: -2.3324, Loss D: -0.0705
# Epoch 453, Loss G: -2.1642, Loss D: 0.0211
# Epoch 454, Loss G: -2.1984, Loss D: 0.0531
# Epoch 455, Loss G: -2.2294, Loss D: -0.0045
# Epoch 456, Loss G: -2.3069, Loss D: -0.0234
# Epoch 457, Loss G: -2.3129, Loss D: -0.0514
# Epoch 458, Loss G: -2.1084, Loss D: 0.0580
# Epoch 459, Loss G: -2.3351, Loss D: -0.0545
# Epoch 460, Loss G: -2.3409, Loss D: 0.0065
# Epoch 461, Loss G: -2.2390, Loss D: 0.0315
# Epoch 462, Loss G: -2.2469, Loss D: -0.0291
# Epoch 463, Loss G: -2.3055, Loss D: -0.0606
# Epoch 464, Loss G: -2.1730, Loss D: -0.1034
# Epoch 465, Loss G: -2.2555, Loss D: 0.0239
# Epoch 466, Loss G: -2.2201, Loss D: 0.0602
# Epoch 467, Loss G: -2.2657, Loss D: -0.0075
# Epoch 468, Loss G: -2.4176, Loss D: -0.0749
# Epoch 469, Loss G: -2.3234, Loss D: -0.0445
# Epoch 470, Loss G: -2.2495, Loss D: 0.0218
# Epoch 471, Loss G: -2.2957, Loss D: 0.0120
# Epoch 472, Loss G: -2.2215, Loss D: 0.0113
# Epoch 473, Loss G: -2.2646, Loss D: -0.0639
# Epoch 474, Loss G: -2.3532, Loss D: 0.0508
# Epoch 475, Loss G: -2.3264, Loss D: -0.0630
# Epoch 476, Loss G: -2.2123, Loss D: -0.0020
# Epoch 477, Loss G: -2.3344, Loss D: 0.0311
# Epoch 478, Loss G: -2.2265, Loss D: -0.0591
# Epoch 479, Loss G: -2.2652, Loss D: 0.0446
# Epoch 480, Loss G: -2.3572, Loss D: 0.0229
# Epoch 481, Loss G: -2.3257, Loss D: -0.0944
# Epoch 482, Loss G: -2.1826, Loss D: 0.0300
# Epoch 483, Loss G: -2.2160, Loss D: 0.0431
# Epoch 484, Loss G: -2.3338, Loss D: -0.1179
# Epoch 485, Loss G: -2.2568, Loss D: -0.0069
# Epoch 486, Loss G: -2.2882, Loss D: -0.0106
# Epoch 487, Loss G: -2.3281, Loss D: -0.1278
# Epoch 488, Loss G: -2.2044, Loss D: -0.0814
# Epoch 489, Loss G: -2.2422, Loss D: -0.0983
# Epoch 490, Loss G: -2.3274, Loss D: -0.0846
# Epoch 491, Loss G: -2.2528, Loss D: 0.0392
# Epoch 492, Loss G: -2.3796, Loss D: -0.0143
# Epoch 493, Loss G: -2.1553, Loss D: -0.0379
# Epoch 494, Loss G: -2.2965, Loss D: 0.1071
# Epoch 495, Loss G: -2.3487, Loss D: 0.0018
# Epoch 496, Loss G: -2.2908, Loss D: -0.0569
# Epoch 497, Loss G: -2.1950, Loss D: -0.0102
# Epoch 498, Loss G: -2.4178, Loss D: -0.0524
# Epoch 499, Loss G: -2.3329, Loss D: -0.0638
# Epoch 500, Loss G: -2.2893, Loss D: 0.0449
# Epoch 501, Loss G: -2.3154, Loss D: 0.0477
# Epoch 502, Loss G: -2.2372, Loss D: -0.0578
# Epoch 503, Loss G: -2.3250, Loss D: 0.0023
# Epoch 504, Loss G: -2.2870, Loss D: 0.0118
# Epoch 505, Loss G: -2.3559, Loss D: -0.0101
# Epoch 506, Loss G: -2.2687, Loss D: 0.0505
# Epoch 507, Loss G: -2.2809, Loss D: -0.0363
# Epoch 508, Loss G: -2.2463, Loss D: 0.0710
# Epoch 509, Loss G: -2.2256, Loss D: 0.0219
# Epoch 510, Loss G: -2.2368, Loss D: 0.0758
# Epoch 511, Loss G: -2.3730, Loss D: 0.0443
# Epoch 512, Loss G: -2.2221, Loss D: -0.0281
# Epoch 513, Loss G: -2.2477, Loss D: 0.0666
# Epoch 514, Loss G: -2.2848, Loss D: 0.0821
# Epoch 515, Loss G: -2.2583, Loss D: 0.0045
# Epoch 516, Loss G: -2.2341, Loss D: -0.0153
# Epoch 517, Loss G: -2.3336, Loss D: -0.0458
# Epoch 518, Loss G: -2.2326, Loss D: 0.0255
# Epoch 519, Loss G: -2.3516, Loss D: -0.0950
# Epoch 520, Loss G: -2.2528, Loss D: 0.0364
# Epoch 521, Loss G: -2.2133, Loss D: -0.0190
# Epoch 522, Loss G: -2.4136, Loss D: 0.0032
# Epoch 523, Loss G: -2.2695, Loss D: -0.0032
# Epoch 524, Loss G: -2.3334, Loss D: 0.0971
# Epoch 525, Loss G: -2.4206, Loss D: 0.0590
# Epoch 526, Loss G: -2.3159, Loss D: -0.0158
# Epoch 527, Loss G: -2.3463, Loss D: -0.0019
# Epoch 528, Loss G: -2.2255, Loss D: -0.1366
# Epoch 529, Loss G: -2.3118, Loss D: -0.0215
# Epoch 530, Loss G: -2.2371, Loss D: 0.0570
# Epoch 531, Loss G: -2.2795, Loss D: -0.0349
# Epoch 532, Loss G: -2.3075, Loss D: -0.0496
# Epoch 533, Loss G: -2.2795, Loss D: 0.0392
# Epoch 534, Loss G: -2.3001, Loss D: -0.0023
# Epoch 535, Loss G: -2.1893, Loss D: 0.0139
# Epoch 536, Loss G: -2.3493, Loss D: -0.0168
# Epoch 537, Loss G: -2.3374, Loss D: -0.0042
# Epoch 538, Loss G: -2.2279, Loss D: 0.0067
# Epoch 539, Loss G: -2.2801, Loss D: -0.0320
# Epoch 540, Loss G: -2.2888, Loss D: -0.0270
# Epoch 541, Loss G: -2.3403, Loss D: 0.0159
# Epoch 542, Loss G: -2.2505, Loss D: 0.0460
# Epoch 543, Loss G: -2.2259, Loss D: -0.0165
# Epoch 544, Loss G: -2.3091, Loss D: 0.0241
# Epoch 545, Loss G: -2.3024, Loss D: -0.0370
# Epoch 546, Loss G: -2.3578, Loss D: 0.0159
# Epoch 547, Loss G: -2.2610, Loss D: -0.0574
# Epoch 548, Loss G: -2.3370, Loss D: 0.0231
# Epoch 549, Loss G: -2.3437, Loss D: -0.0016
# Epoch 550, Loss G: -2.1838, Loss D: -0.0037
# Epoch 551, Loss G: -2.3515, Loss D: -0.0499
# Epoch 552, Loss G: -2.2724, Loss D: -0.0045
# Epoch 553, Loss G: -2.2270, Loss D: -0.0062
# Epoch 554, Loss G: -2.2658, Loss D: -0.1165
# Epoch 555, Loss G: -2.2286, Loss D: -0.0699
# Epoch 556, Loss G: -2.4070, Loss D: -0.0497
# Epoch 557, Loss G: -2.3462, Loss D: -0.0210
# Epoch 558, Loss G: -2.2729, Loss D: -0.0549
# Epoch 559, Loss G: -2.4416, Loss D: 0.0211
# Epoch 560, Loss G: -2.1980, Loss D: -0.0131
# Epoch 561, Loss G: -2.3046, Loss D: 0.0972
# Epoch 562, Loss G: -2.3146, Loss D: -0.1021
# Epoch 563, Loss G: -2.3274, Loss D: 0.0093
# Epoch 564, Loss G: -2.2403, Loss D: 0.0048
# Epoch 565, Loss G: -2.3052, Loss D: -0.0702
# Epoch 566, Loss G: -2.2343, Loss D: 0.0821
# Epoch 567, Loss G: -2.2738, Loss D: -0.0281
# Epoch 568, Loss G: -2.2158, Loss D: -0.0174
# Epoch 569, Loss G: -2.2925, Loss D: -0.0546
# Epoch 570, Loss G: -2.2970, Loss D: -0.0611
# Epoch 571, Loss G: -2.3804, Loss D: -0.0228
# Epoch 572, Loss G: -2.2186, Loss D: -0.0259
# Epoch 573, Loss G: -2.2389, Loss D: -0.1164
# Epoch 574, Loss G: -2.2098, Loss D: 0.0832
# Epoch 575, Loss G: -2.3629, Loss D: 0.0009
# Epoch 576, Loss G: -2.2206, Loss D: -0.0806
# Epoch 577, Loss G: -2.4278, Loss D: 0.0252
# Epoch 578, Loss G: -2.2655, Loss D: 0.0011
# Epoch 579, Loss G: -2.2264, Loss D: -0.0342
# Epoch 580, Loss G: -2.3366, Loss D: 0.0143
# Epoch 581, Loss G: -2.3792, Loss D: -0.0401
# Epoch 582, Loss G: -2.3068, Loss D: -0.0299
# Epoch 583, Loss G: -2.2491, Loss D: 0.0276
# Epoch 584, Loss G: -2.2857, Loss D: 0.0292
# Epoch 585, Loss G: -2.1568, Loss D: 0.0368
# Epoch 586, Loss G: -2.2039, Loss D: 0.0164
# Epoch 587, Loss G: -2.3168, Loss D: -0.0526
# Epoch 588, Loss G: -2.2369, Loss D: 0.0339
# Epoch 589, Loss G: -2.1620, Loss D: 0.0240
# Epoch 590, Loss G: -2.2126, Loss D: 0.0151
# Epoch 591, Loss G: -2.3134, Loss D: -0.0627
# Epoch 592, Loss G: -2.2447, Loss D: 0.0549
# Epoch 593, Loss G: -2.4146, Loss D: 0.0321
# Epoch 594, Loss G: -2.2683, Loss D: -0.0738
# Epoch 595, Loss G: -2.2956, Loss D: -0.0407
# Epoch 596, Loss G: -2.2723, Loss D: -0.0210
# Epoch 597, Loss G: -2.1436, Loss D: -0.0058
# Epoch 598, Loss G: -2.3661, Loss D: -0.0935
# Epoch 599, Loss G: -2.3086, Loss D: 0.0797
# Epoch 600, Loss G: -2.2146, Loss D: -0.0439

# %% [markdown]
# # CTGAN
#
# Adapted from `generate_ctgan_<dataset>.py`

# %%
def sample_CTGAN(df, dataset="occutherm", logs=False):
    # load require samples to balance and initial count
    if dataset == "occutherm":
        # samples to generate per label
        occutherm_req_one = 342
        occutherm_req_zero = 0 
        occutherm_req_minus_one = 603
        # count of generated samples per label
        count_one = 0
        count_minus_one = 0
    elif dataset == "cresh":
        # samples to generate per label
        cresh_req_nine = 547
        cresh_req_ten = 0
        cresh_req_eleven = 433
        # count of generated samples per label
        count_nine = 0
        count_eleven = 0
    elif dataset == "ashrae":
        # samples to generate per label
        ashrae_req_one = 7686 
        ashrae_req_zero = 0
        ashrae_req_minus_one = 3167
        # count of generated samples per label
        count_one = 0
        count_minus_one = 0
        
    samples_count = 0 # total number of samples generated
    finish_loop = False
    
    # samples to generated every loop
    if dataset == "ashrae":
        print_threshold = 10000
    else:
        print_threshold = 3000
    
    # initiliaze synthetic dataframe
    columns = df.columns.values
    df_synth = pd.DataFrame(columns=columns)
    
    # load model
    model_path = "models/ctgan_" + dataset + "_reduced" + ".pkl"
    ctgan = pickle.load(open( model_path, "rb" ))

    while True:
        if finish_loop:
            samples_count += print_threshold
            break
        
        # generate `print_threshold` samples
        curr_df = ctgan.sample(print_threshold)
        
#         print(curr_df.iloc[:, -1].unique())
        
        # iterate through the generated samples
        if dataset == "occutherm":
            for index, row in curr_df.iterrows():  
                if (row['Discrete Thermal Comfort_TA'] == 1) and (count_one != occutherm_req_one): 
                    df_synth = df_synth.append(row)
                    count_one += 1
                elif (row['Discrete Thermal Comfort_TA'] == -1) and (count_minus_one != occutherm_req_minus_one): 
                    df_synth = df_synth.append(row)
                    count_minus_one += 1
                elif (count_one == occutherm_req_one) and \
                    (count_minus_one == occutherm_req_minus_one):
                    finish_loop = True
                    break
                  
        elif dataset == "cresh":
            for index, row in curr_df.iterrows():  
                if (row['thermal_cozie'] == 9) and (count_nine != cresh_req_nine): 
                    df_synth = df_synth.append(row)
                    count_nine += 1 
                elif (row['thermal_cozie'] == 11) and (count_eleven != cresh_req_eleven): 
                    df_synth = df_synth.append(row)
                    count_eleven += 1
                elif (count_nine == cresh_req_nine) and (count_eleven == cresh_req_eleven):
                    finish_loop = True
                    break

        elif dataset == "ashrae":
            for index, row in curr_df.iterrows(): 
                if (row['Thermal sensation rounded'] == 1) and (count_one != ashrae_req_one): 
                    df_synth = df_synth.append(row)
                    count_one += 1
                elif (row['Thermal sensation rounded'] == -1) and (count_minus_one != ashrae_req_minus_one): 
                    df_synth = df_synth.append(row)
                    count_minus_one += 1
                elif (count_one == ashrae_req_one) and \
                     (count_minus_one == ashrae_req_minus_one):
                    finish_loop = True
                    break

        samples_count += print_threshold

    if logs:
        print('Original {} train dataset shape {}'.format(df, Counter(y)))        
        print('Resampled (CTGAN) synth dataset shape %s' % Counter(np.array(df_synth.iloc[:, -1])))

    if dataset == "occutherm":
        df_synth['Gender'] = pd.to_numeric(df_synth['Gender'], errors='coerce')
    # last column in float instead of string
    df_synth.iloc[:, -1] = pd.to_numeric(df_synth.iloc[:, -1], errors='coerce')

    return df_synth

# %%
def evaluate_on_dataset(df_train, df_test, dataset='occutherm'):
    model = 'ctgan'
    # empty list to hold values during trials
    variability_list = []
    diversity_list = []

    class_acc_test_list_0 = []
    class_acc_test_list_1 = []
    class_acc_test_list_2 = []
    class_acc_test_list_3 = []
    
    class_report_rdf_list = []
        
    for i in range(0, num_trials):      
        ###################################
        # Sample synthethic dataset for 'dataset'
        df_synth = sample_CTGAN(df_train, dataset)

        # merge synthethic + real dataset
        df_real_synth = pd.concat([df_synth, df_train])
                
        ###################################
        # Variability of generated samples
        variability = evaluation_variability(df_synth)
        variability_list.append(variability)
    
        #################################################
        # Class diversity with respect to the training set
        diversity = evaluation_diversity(df_synth, df_train, baseline=False)
        diversity_list.append(diversity)

        #####################################
        # Quality on the final classification
        # use best models NB, KNN, SVM, RDF
        class_acc_test, class_acc_train, class_models, class_report_rdf = evaluation_classification(df_real_synth, df_test, rdf_depth=fixed_depth, depth_file_name='default', test_size_percentage=test_size_percentage)
        class_acc_test_list_0.append(class_acc_test[0])
        class_acc_test_list_1.append(class_acc_test[1])
        class_acc_test_list_2.append(class_acc_test[2])
        class_acc_test_list_3.append(class_acc_test[3])
        class_report_rdf_list.append(class_report_rdf)
        
        ########################
        # end of for loop trials
        print("End of {} trial".format(i + 1))
        
    # get average of trials
    variability = mean(variability_list)
    diversity = mean(diversity_list)
    class_acc_test = [mean(class_acc_test_list_0), mean(class_acc_test_list_1), mean(class_acc_test_list_2), mean(class_acc_test_list_3)]
    
    #####################################
    # Saving results
    # Format is folder/<dataset_string>-<experiment_name>_<metric or model>_<test or train>_<model>.pkl
    save_pickle(variability, "metrics/" + dataset + "-reduced" + "_variability_" + model + "_trials.pkl")
    save_pickle(diversity, "metrics/" + dataset + "-reduced" + "_diversity_" + model + "_trials.pkl")
    save_pickle(class_acc_test, "metrics/" + dataset + "-reduced" + "_classification_" + model + "_trials.pkl")
    save_pickle(class_report_rdf_list, "label-metrics/" + dataset + "-reduced" + "_class_report_" + model + "_trials.pkl")
    
    print("################################################################################")
    print("# Metrics and models for dataset {} saved!".format(dataset))
    print("################################################################################")

# %% [markdown]
# ## Occutherm

# %%
evaluate_on_dataset(df_tcs_train, df_tcs_test, dataset='occutherm')
# Out:
# End of 1 trial
# End of 2 trial
# End of 3 trial
# End of 4 trial
# End of 5 trial
# End of 6 trial
# End of 7 trial
# End of 8 trial
# End of 9 trial
# End of 10 trial
# End of 11 trial
# End of 12 trial
# End of 13 trial
# End of 14 trial
# End of 15 trial
# End of 16 trial
# End of 17 trial
# End of 18 trial
# End of 19 trial
# End of 20 trial
# End of 21 trial
# End of 22 trial
# End of 23 trial
# End of 24 trial
# End of 25 trial
# End of 26 trial
# End of 27 trial
# End of 28 trial
# End of 29 trial
# End of 30 trial
# ################################################################################
# # Metrics and models for dataset occutherm saved!
# ################################################################################

# %% [markdown]
# ## Cresh

# %% [markdown]
# ## ASHRAE

# %%
evaluate_on_dataset(df_ashrae_train, df_ashrae_test, dataset='ashrae')
# Out:
# End of 1 trial
# End of 2 trial
# End of 3 trial
# End of 4 trial
# End of 5 trial
# End of 6 trial
# End of 7 trial
# End of 8 trial
# End of 9 trial
# End of 10 trial
# End of 11 trial
# End of 12 trial
# End of 13 trial
# End of 14 trial
# End of 15 trial
# End of 16 trial
# End of 17 trial
# End of 18 trial
# End of 19 trial
# End of 20 trial
# End of 21 trial
# End of 22 trial
# End of 23 trial
# End of 24 trial
# End of 25 trial
# End of 26 trial
# End of 27 trial
# End of 28 trial
# End of 29 trial
# End of 30 trial
# ################################################################################
# # Metrics and models for dataset ashrae saved!
# ################################################################################
