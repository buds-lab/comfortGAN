# %%
# Notebooks
import nbimporter
import os
import sys

# Functions from src
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# Defined Functions
from utils import *

# Pandas, matplotlib, pickle, seaborn
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from statistics import mean
from collections import Counter
from ctgan import CTGANSynthesizer

random_state = 13

# %%
# global variables/constants
num_trials = 30
test_size_percentage = 0.2 # for CV within train split
fixed_depth = 10

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Occutherm

# %%
df_tcs_train = pd.read_pickle("data/occutherm/df_feature1_train.pkl") 
df_tcs_test = pd.read_pickle("data/occutherm/df_feature1_test.pkl")

# total count for instances per class: 818
print(df_tcs_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 10 columns):
# Temperature (Fahrenheit)       1508 non-null float64
# SkinTemperature                1508 non-null float64
# ClothingInsulation             1508 non-null float64
# Height(cm)                     1508 non-null float64
# Shoulder Circumference(cm)     1508 non-null float64
# Weight(lbs)                    1508 non-null float64
# Gender                         1508 non-null int64
# Temperature_outside            1508 non-null float64
# Humidity_outside               1508 non-null float64
# Discrete Thermal Comfort_TA    1508 non-null int64
# dtypes: float64(8), int64(2)
# memory usage: 117.9 KB
# None

# %% [markdown]
# ## Cresh

# %%
df_cresh_train = pd.read_pickle("data/cresh/cresh_train.pkl")
df_cresh_test = pd.read_pickle("data/cresh/cresh_test.pkl")

# total count for instances per class: 713
print(df_cresh_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159 entries, 0 to 1158
# Data columns (total 11 columns):
# heartRate_cozie        1159 non-null float64
# humidity_sensing       1159 non-null float64
# light_sensing          1159 non-null float64
# noise_sensing          1159 non-null float64
# temperature_sensing    1159 non-null float64
# temperature_mbient     1159 non-null float64
# hour_sin               1159 non-null float64
# hour_cos               1159 non-null float64
# day_of_week_sin        1159 non-null float64
# day_of_week_cos        1159 non-null float64
# thermal_cozie          1159 non-null int64
# dtypes: float64(10), int64(1)
# memory usage: 99.7 KB
# None

# %% [markdown]
# ## ASHRAE

# %%
df_ashrae_train = pd.read_pickle("data/ashrae/ashrae_train.pkl")
df_ashrae_test = pd.read_pickle("data/ashrae/ashrae_test.pkl")

print(df_ashrae_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46477 entries, 0 to 46476
# Data columns (total 7 columns):
# SET                          46477 non-null float64
# Clo                          46477 non-null float64
# Met                          46477 non-null float64
# Air temperature (¡C)         46477 non-null float64
# Relative humidity (%)        46477 non-null float64
# Air velocity (m/s)           46477 non-null float64
# Thermal sensation rounded    46477 non-null float64
# dtypes: float64(7)
# memory usage: 2.5 MB
# None

# %% [markdown]
# # Samplig synthetic datasets
#
# https://sdv-dev.github.io/CTGAN/
#
# https://github.com/sdv-dev/CTGAN
#
# Models can be trained directly on this notebooks and then single synthetic datasets can be generated by running the file `generate_ctgan_<dataset>.py`. However, for this noteboooks since `num_trials` of synthetic datasets will be generated, the script is adapted below.

# %% [markdown]
# ## Occutherm
# Required samples
#
# | Model | -2 | -1 | 0 | 1 | 2 |
# |---|---|---|---|---|---|
# | SMOTE | 646 | 515 | 0 | 647 | 774 |
# | ADASYN | 651 | 519 | 0 | 680 | 770 |

# %%
discrete_columns_occutherm = [
    'Gender',
    'Discrete Thermal Comfort_TA'
]

ctgan_occutherm = CTGANSynthesizer()
ctgan_occutherm.fit(df_tcs_train, discrete_columns_occutherm) #epochs=300
save_pickle(ctgan_occutherm, "models/ctgan_occutherm.pkl")
# Out:
# Epoch 1, Loss G: 1.1149, Loss D: 0.0095
# Epoch 2, Loss G: 1.0254, Loss D: 0.0247
# Epoch 3, Loss G: 0.9356, Loss D: -0.0215
# Epoch 4, Loss G: 0.9791, Loss D: -0.0518
# Epoch 5, Loss G: 0.8646, Loss D: 0.0126
# Epoch 6, Loss G: 0.7581, Loss D: -0.1192
# Epoch 7, Loss G: 0.6541, Loss D: -0.1034
# Epoch 8, Loss G: 0.6203, Loss D: -0.1120
# Epoch 9, Loss G: 0.4839, Loss D: -0.0668
# Epoch 10, Loss G: 0.3786, Loss D: 0.1177
# Epoch 11, Loss G: 0.2656, Loss D: -0.0821
# Epoch 12, Loss G: 0.2667, Loss D: 0.1129
# Epoch 13, Loss G: 0.2395, Loss D: 0.0337
# Epoch 14, Loss G: 0.3670, Loss D: -0.0791
# Epoch 15, Loss G: 0.3724, Loss D: -0.0884
# Epoch 16, Loss G: 0.3650, Loss D: -0.1650
# Epoch 17, Loss G: 0.2684, Loss D: -0.2133
# Epoch 18, Loss G: 0.2069, Loss D: -0.0918
# Epoch 19, Loss G: 0.1664, Loss D: 0.0681
# Epoch 20, Loss G: 0.1318, Loss D: 0.0726
# Epoch 21, Loss G: 0.1020, Loss D: 0.0265
# Epoch 22, Loss G: 0.1198, Loss D: -0.0350
# Epoch 23, Loss G: 0.1418, Loss D: -0.0547
# Epoch 24, Loss G: 0.2757, Loss D: 0.0611
# Epoch 25, Loss G: 0.1752, Loss D: 0.1061
# Epoch 26, Loss G: 0.0028, Loss D: 0.0979
# Epoch 27, Loss G: 0.0721, Loss D: 0.1831
# Epoch 28, Loss G: 0.0171, Loss D: 0.2797
# Epoch 29, Loss G: -0.0435, Loss D: 0.1872
# Epoch 30, Loss G: 0.0166, Loss D: -0.0126
# Epoch 31, Loss G: 0.1470, Loss D: -0.0829
# Epoch 32, Loss G: 0.1590, Loss D: -0.1796
# Epoch 33, Loss G: 0.1431, Loss D: -0.2311
# Epoch 34, Loss G: 0.0638, Loss D: -0.3151
# Epoch 35, Loss G: -0.0563, Loss D: -0.0105
# Epoch 36, Loss G: -0.2046, Loss D: 0.1363
# Epoch 37, Loss G: -0.2152, Loss D: 0.0942
# Epoch 38, Loss G: -0.3210, Loss D: 0.1359
# Epoch 39, Loss G: -0.4659, Loss D: 0.0669
# Epoch 40, Loss G: -0.3199, Loss D: 0.0818
# Epoch 41, Loss G: -0.2261, Loss D: 0.0406
# Epoch 42, Loss G: -0.3114, Loss D: 0.1044
# Epoch 43, Loss G: -0.4365, Loss D: 0.1481
# Epoch 44, Loss G: -0.4628, Loss D: 0.3083
# Epoch 45, Loss G: -0.4649, Loss D: 0.1485
# Epoch 46, Loss G: -0.5195, Loss D: 0.2431
# Epoch 47, Loss G: -0.4581, Loss D: 0.1718
# Epoch 48, Loss G: -0.5146, Loss D: 0.0264
# Epoch 49, Loss G: -0.4368, Loss D: -0.0828
# Epoch 50, Loss G: -0.4099, Loss D: -0.1715
# Epoch 51, Loss G: -0.4222, Loss D: -0.0864
# Epoch 52, Loss G: -0.6440, Loss D: -0.0809
# Epoch 53, Loss G: -0.7015, Loss D: 0.0131
# Epoch 54, Loss G: -0.7410, Loss D: 0.1645
# Epoch 55, Loss G: -0.7670, Loss D: 0.1102
# Epoch 56, Loss G: -0.6818, Loss D: 0.1335
# Epoch 57, Loss G: -0.6324, Loss D: -0.0587
# Epoch 58, Loss G: -0.4781, Loss D: -0.1505
# Epoch 59, Loss G: -0.4786, Loss D: -0.2999
# Epoch 60, Loss G: -0.5167, Loss D: -0.0035
# Epoch 61, Loss G: -0.7954, Loss D: 0.0596
# Epoch 62, Loss G: -0.8704, Loss D: 0.1130
# Epoch 63, Loss G: -0.9994, Loss D: 0.1196
# Epoch 64, Loss G: -0.9676, Loss D: 0.0802
# Epoch 65, Loss G: -0.9366, Loss D: 0.1706
# Epoch 66, Loss G: -0.8392, Loss D: -0.0758
# Epoch 67, Loss G: -0.6761, Loss D: -0.2968
# Epoch 68, Loss G: -0.7772, Loss D: -0.1843
# Epoch 69, Loss G: -0.9042, Loss D: -0.2643
# Epoch 70, Loss G: -1.0517, Loss D: 0.0255
# Epoch 71, Loss G: -1.1299, Loss D: 0.0074
# Epoch 72, Loss G: -1.0258, Loss D: 0.1544
# Epoch 73, Loss G: -1.0950, Loss D: -0.0027
# Epoch 74, Loss G: -0.9863, Loss D: 0.1583
# Epoch 75, Loss G: -0.9766, Loss D: -0.0272
# Epoch 76, Loss G: -1.0677, Loss D: 0.0991
# Epoch 77, Loss G: -1.1134, Loss D: 0.1483
# Epoch 78, Loss G: -1.1574, Loss D: 0.0994
# Epoch 79, Loss G: -1.0802, Loss D: -0.0187
# Epoch 80, Loss G: -1.0248, Loss D: -0.0732
# Epoch 81, Loss G: -1.0886, Loss D: -0.0532
# Epoch 82, Loss G: -1.1057, Loss D: 0.0738
# Epoch 83, Loss G: -1.1761, Loss D: 0.0776
# Epoch 84, Loss G: -1.2339, Loss D: 0.1714
# Epoch 85, Loss G: -1.1608, Loss D: -0.0830
# Epoch 86, Loss G: -1.1250, Loss D: -0.0043
# Epoch 87, Loss G: -1.1215, Loss D: -0.1659
# Epoch 88, Loss G: -0.9634, Loss D: -0.0910
# Epoch 89, Loss G: -1.0131, Loss D: 0.0330
# Epoch 90, Loss G: -1.1074, Loss D: -0.0756
# Epoch 91, Loss G: -1.1233, Loss D: -0.0734
# Epoch 92, Loss G: -1.1058, Loss D: -0.0922
# Epoch 93, Loss G: -1.0548, Loss D: -0.2720
# Epoch 94, Loss G: -1.0165, Loss D: -0.0609
# Epoch 95, Loss G: -1.2581, Loss D: -0.0547
# Epoch 96, Loss G: -1.2509, Loss D: -0.0401
# Epoch 97, Loss G: -1.2414, Loss D: 0.0880
# Epoch 98, Loss G: -1.3232, Loss D: 0.0270
# Epoch 99, Loss G: -1.1546, Loss D: 0.0116
# Epoch 100, Loss G: -1.3459, Loss D: 0.1287
# Epoch 101, Loss G: -1.4679, Loss D: 0.1346
# Epoch 102, Loss G: -1.3813, Loss D: 0.1387
# Epoch 103, Loss G: -1.4293, Loss D: 0.0881
# Epoch 104, Loss G: -1.4093, Loss D: 0.0675
# Epoch 105, Loss G: -1.5142, Loss D: 0.0007
# Epoch 106, Loss G: -1.4377, Loss D: 0.0222
# Epoch 107, Loss G: -1.3009, Loss D: 0.0333
# Epoch 108, Loss G: -1.2881, Loss D: -0.0678
# Epoch 109, Loss G: -1.3410, Loss D: -0.0702
# Epoch 110, Loss G: -1.3635, Loss D: -0.0803
# Epoch 111, Loss G: -1.5018, Loss D: 0.1317
# Epoch 112, Loss G: -1.6059, Loss D: 0.0441
# Epoch 113, Loss G: -1.5990, Loss D: 0.0476
# Epoch 114, Loss G: -1.5842, Loss D: 0.0847
# Epoch 115, Loss G: -1.6717, Loss D: 0.0436
# Epoch 116, Loss G: -1.6495, Loss D: -0.0216
# Epoch 117, Loss G: -1.6368, Loss D: 0.0948
# Epoch 118, Loss G: -1.5306, Loss D: -0.0395
# Epoch 119, Loss G: -1.6307, Loss D: -0.1025
# Epoch 120, Loss G: -1.6634, Loss D: -0.0315
# Epoch 121, Loss G: -1.6929, Loss D: -0.1707
# Epoch 122, Loss G: -1.6226, Loss D: -0.0456
# Epoch 123, Loss G: -1.6009, Loss D: -0.0095
# Epoch 124, Loss G: -1.7667, Loss D: 0.0220
# Epoch 125, Loss G: -1.8245, Loss D: 0.0099
# Epoch 126, Loss G: -1.7303, Loss D: 0.1361
# Epoch 127, Loss G: -1.6884, Loss D: 0.1009
# Epoch 128, Loss G: -1.6103, Loss D: 0.0430
# Epoch 129, Loss G: -1.6422, Loss D: -0.0441
# Epoch 130, Loss G: -1.5770, Loss D: 0.0456
# Epoch 131, Loss G: -1.5526, Loss D: -0.0078
# Epoch 132, Loss G: -1.4847, Loss D: -0.0500
# Epoch 133, Loss G: -1.5475, Loss D: 0.0842
# Epoch 134, Loss G: -1.5057, Loss D: 0.1205
# Epoch 135, Loss G: -1.5800, Loss D: -0.0158
# Epoch 136, Loss G: -1.5855, Loss D: 0.0751
# Epoch 137, Loss G: -1.5617, Loss D: 0.0406
# Epoch 138, Loss G: -1.4797, Loss D: -0.0596
# Epoch 139, Loss G: -1.5394, Loss D: -0.0198
# Epoch 140, Loss G: -1.6828, Loss D: 0.0892
# Epoch 141, Loss G: -1.5424, Loss D: 0.0765
# Epoch 142, Loss G: -1.6097, Loss D: 0.1180
# Epoch 143, Loss G: -1.6987, Loss D: -0.0604
# Epoch 144, Loss G: -1.6137, Loss D: -0.0084
# Epoch 145, Loss G: -1.5934, Loss D: -0.0202
# Epoch 146, Loss G: -1.4991, Loss D: -0.1247
# Epoch 147, Loss G: -1.6293, Loss D: -0.1484
# Epoch 148, Loss G: -1.7241, Loss D: -0.0084
# Epoch 149, Loss G: -1.6267, Loss D: -0.0160
# Epoch 150, Loss G: -1.6374, Loss D: 0.0075
# Epoch 151, Loss G: -1.7252, Loss D: 0.0528
# Epoch 152, Loss G: -1.6456, Loss D: -0.0036
# Epoch 153, Loss G: -1.7192, Loss D: -0.0171
# Epoch 154, Loss G: -1.7917, Loss D: -0.0274
# Epoch 155, Loss G: -1.8326, Loss D: 0.0351
# Epoch 156, Loss G: -1.6962, Loss D: 0.1292
# Epoch 157, Loss G: -1.8053, Loss D: 0.1982
# Epoch 158, Loss G: -1.8413, Loss D: 0.0456
# Epoch 159, Loss G: -1.9623, Loss D: -0.0325
# Epoch 160, Loss G: -1.8305, Loss D: 0.0587
# Epoch 161, Loss G: -1.8062, Loss D: 0.1733
# Epoch 162, Loss G: -1.6750, Loss D: -0.0541
# Epoch 163, Loss G: -1.6843, Loss D: -0.1470
# Epoch 164, Loss G: -1.4919, Loss D: -0.2772
# Epoch 165, Loss G: -1.4920, Loss D: -0.2454
# Epoch 166, Loss G: -1.5659, Loss D: -0.1467
# Epoch 167, Loss G: -1.6516, Loss D: -0.0674
# Epoch 168, Loss G: -1.6903, Loss D: 0.0379
# Epoch 169, Loss G: -1.6924, Loss D: 0.0096
# Epoch 170, Loss G: -1.7773, Loss D: -0.1179
# Epoch 171, Loss G: -1.7824, Loss D: -0.0919
# Epoch 172, Loss G: -1.8129, Loss D: -0.0934
# Epoch 173, Loss G: -1.8654, Loss D: -0.0286
# Epoch 174, Loss G: -1.8457, Loss D: -0.0503
# Epoch 175, Loss G: -1.9034, Loss D: 0.0639
# Epoch 176, Loss G: -1.9127, Loss D: 0.1567
# Epoch 177, Loss G: -1.9184, Loss D: 0.0720
# Epoch 178, Loss G: -2.0006, Loss D: -0.0855
# Epoch 179, Loss G: -1.8148, Loss D: 0.0305
# Epoch 180, Loss G: -1.8090, Loss D: -0.0328
# Epoch 181, Loss G: -1.8123, Loss D: -0.0532
# Epoch 182, Loss G: -1.6763, Loss D: -0.0769
# Epoch 183, Loss G: -1.8556, Loss D: -0.0415
# Epoch 184, Loss G: -1.8076, Loss D: 0.1054
# Epoch 185, Loss G: -1.7654, Loss D: -0.0480
# Epoch 186, Loss G: -1.6319, Loss D: -0.0852
# Epoch 187, Loss G: -1.6548, Loss D: -0.1135
# Epoch 188, Loss G: -1.6473, Loss D: -0.0897
# Epoch 189, Loss G: -1.6867, Loss D: 0.0915
# Epoch 190, Loss G: -1.7704, Loss D: 0.1298
# Epoch 191, Loss G: -1.8060, Loss D: 0.0930
# Epoch 192, Loss G: -1.7502, Loss D: 0.1792
# Epoch 193, Loss G: -1.6128, Loss D: -0.0624
# Epoch 194, Loss G: -1.6802, Loss D: -0.0393
# Epoch 195, Loss G: -1.7064, Loss D: -0.0689
# Epoch 196, Loss G: -1.6546, Loss D: 0.1113
# Epoch 197, Loss G: -1.6654, Loss D: -0.1418
# Epoch 198, Loss G: -1.6024, Loss D: 0.0126
# Epoch 199, Loss G: -1.6854, Loss D: -0.0535
# Epoch 200, Loss G: -1.7274, Loss D: -0.0572
# Epoch 201, Loss G: -1.6905, Loss D: -0.0974
# Epoch 202, Loss G: -1.6329, Loss D: 0.1112
# Epoch 203, Loss G: -1.6048, Loss D: -0.1870
# Epoch 204, Loss G: -1.5868, Loss D: -0.2117
# Epoch 205, Loss G: -1.5496, Loss D: -0.0395
# Epoch 206, Loss G: -1.6422, Loss D: -0.0682
# Epoch 207, Loss G: -1.7394, Loss D: 0.0129
# Epoch 208, Loss G: -1.7281, Loss D: -0.0883
# Epoch 209, Loss G: -1.6646, Loss D: 0.0501
# Epoch 210, Loss G: -1.7812, Loss D: -0.0362
# Epoch 211, Loss G: -1.7395, Loss D: 0.0052
# Epoch 212, Loss G: -1.8513, Loss D: 0.0867
# Epoch 213, Loss G: -1.8919, Loss D: 0.0328
# Epoch 214, Loss G: -1.8889, Loss D: 0.1078
# Epoch 215, Loss G: -1.9730, Loss D: 0.1802
# Epoch 216, Loss G: -1.8953, Loss D: 0.0517
# Epoch 217, Loss G: -1.8106, Loss D: 0.0614
# Epoch 218, Loss G: -1.7092, Loss D: 0.0102
# Epoch 219, Loss G: -1.6017, Loss D: -0.2831
# Epoch 220, Loss G: -1.4924, Loss D: -0.3737
# Epoch 221, Loss G: -1.6305, Loss D: -0.1950
# Epoch 222, Loss G: -1.6158, Loss D: -0.3266
# Epoch 223, Loss G: -1.7400, Loss D: -0.0087
# Epoch 224, Loss G: -1.9455, Loss D: 0.0606
# Epoch 225, Loss G: -1.9238, Loss D: 0.0009
# Epoch 226, Loss G: -1.8917, Loss D: 0.0724
# Epoch 227, Loss G: -1.8664, Loss D: 0.0594
# Epoch 228, Loss G: -1.9260, Loss D: -0.1168
# Epoch 229, Loss G: -1.7831, Loss D: 0.0469
# Epoch 230, Loss G: -1.8580, Loss D: -0.0928
# Epoch 231, Loss G: -1.9314, Loss D: 0.0312
# Epoch 232, Loss G: -1.7593, Loss D: 0.0974
# Epoch 233, Loss G: -1.7446, Loss D: -0.0005
# Epoch 234, Loss G: -1.6461, Loss D: 0.0057
# Epoch 235, Loss G: -1.6841, Loss D: -0.1005
# Epoch 236, Loss G: -1.6168, Loss D: 0.0440
# Epoch 237, Loss G: -1.6218, Loss D: -0.1475
# Epoch 238, Loss G: -1.5918, Loss D: -0.0546
# Epoch 239, Loss G: -1.6020, Loss D: -0.1121
# Epoch 240, Loss G: -1.6495, Loss D: -0.0983
# Epoch 241, Loss G: -1.7461, Loss D: -0.0056
# Epoch 242, Loss G: -1.7407, Loss D: 0.0388
# Epoch 243, Loss G: -1.7237, Loss D: -0.0015
# Epoch 244, Loss G: -1.7062, Loss D: -0.0109
# Epoch 245, Loss G: -1.7559, Loss D: -0.0630
# Epoch 246, Loss G: -1.7315, Loss D: 0.0208
# Epoch 247, Loss G: -1.6832, Loss D: 0.0908
# Epoch 248, Loss G: -1.6802, Loss D: -0.0534
# Epoch 249, Loss G: -1.5864, Loss D: -0.1054
# Epoch 250, Loss G: -1.6876, Loss D: -0.1674
# Epoch 251, Loss G: -1.6162, Loss D: -0.0457
# Epoch 252, Loss G: -1.6625, Loss D: 0.0932
# Epoch 253, Loss G: -1.7530, Loss D: 0.0199
# Epoch 254, Loss G: -1.8629, Loss D: 0.0713
# Epoch 255, Loss G: -1.8099, Loss D: -0.0402
# Epoch 256, Loss G: -1.7061, Loss D: 0.0872
# Epoch 257, Loss G: -1.7563, Loss D: -0.0332
# Epoch 258, Loss G: -1.6611, Loss D: -0.1240
# Epoch 259, Loss G: -1.6871, Loss D: -0.0176
# Epoch 260, Loss G: -1.6232, Loss D: -0.1706
# Epoch 261, Loss G: -1.6527, Loss D: -0.0739
# Epoch 262, Loss G: -1.7650, Loss D: -0.1313
# Epoch 263, Loss G: -1.7040, Loss D: 0.0748
# Epoch 264, Loss G: -1.6682, Loss D: 0.0242
# Epoch 265, Loss G: -1.7327, Loss D: -0.0705
# Epoch 266, Loss G: -1.7658, Loss D: -0.0317
# Epoch 267, Loss G: -1.6448, Loss D: -0.0463
# Epoch 268, Loss G: -1.6446, Loss D: -0.0606
# Epoch 269, Loss G: -1.5961, Loss D: 0.0569
# Epoch 270, Loss G: -1.6594, Loss D: -0.0500
# Epoch 271, Loss G: -1.6384, Loss D: -0.1406
# Epoch 272, Loss G: -1.7342, Loss D: 0.0202
# Epoch 273, Loss G: -1.7056, Loss D: 0.0226
# Epoch 274, Loss G: -1.7099, Loss D: -0.0108
# Epoch 275, Loss G: -1.6811, Loss D: 0.0104
# Epoch 276, Loss G: -1.7137, Loss D: 0.0996
# Epoch 277, Loss G: -1.5770, Loss D: 0.1887
# Epoch 278, Loss G: -1.6272, Loss D: 0.0043
# Epoch 279, Loss G: -1.5165, Loss D: -0.0300
# Epoch 280, Loss G: -1.4799, Loss D: -0.0300
# Epoch 281, Loss G: -1.4731, Loss D: -0.0925
# Epoch 282, Loss G: -1.5553, Loss D: -0.1477
# Epoch 283, Loss G: -1.7066, Loss D: 0.0409
# Epoch 284, Loss G: -1.7117, Loss D: 0.0419
# Epoch 285, Loss G: -1.6964, Loss D: 0.0883
# Epoch 286, Loss G: -1.6909, Loss D: 0.1391
# Epoch 287, Loss G: -1.6947, Loss D: 0.0381
# Epoch 288, Loss G: -1.5782, Loss D: -0.0819
# Epoch 289, Loss G: -1.5134, Loss D: -0.1419
# Epoch 290, Loss G: -1.4699, Loss D: -0.1116
# Epoch 291, Loss G: -1.4582, Loss D: -0.1865
# Epoch 292, Loss G: -1.6063, Loss D: -0.1327
# Epoch 293, Loss G: -1.5865, Loss D: 0.0557
# Epoch 294, Loss G: -1.7281, Loss D: -0.0242
# Epoch 295, Loss G: -1.5741, Loss D: -0.0773
# Epoch 296, Loss G: -1.6047, Loss D: 0.0590
# Epoch 297, Loss G: -1.5740, Loss D: -0.0318
# Epoch 298, Loss G: -1.6162, Loss D: -0.0609
# Epoch 299, Loss G: -1.6485, Loss D: 0.0329
# Epoch 300, Loss G: -1.7402, Loss D: 0.0093

# %% [markdown]
# ## Cresh
# Required samples
#
# | Model | 9 | 10 | 11 |
# |---|---|---|---|
# | SMOTE | 547 | 0 | 433 |
# | ADASYN | 534 | 0 | 402 |

# %%
discrete_columns_cresh = [ # discrete_columns_cresh = [1, 2, 12]
    'thermal_cozie'
]

ctgan_cresh = CTGANSynthesizer()
ctgan_cresh.fit(df_cresh_train, discrete_columns_cresh) #epochs=300
save_pickle(ctgan_cresh, "models/ctgan_cresh.pkl")
# Out:
# Epoch 1, Loss G: 1.1775, Loss D: -0.0260
# Epoch 2, Loss G: 1.2265, Loss D: -0.0278
# Epoch 3, Loss G: 1.1982, Loss D: -0.0596
# Epoch 4, Loss G: 1.1549, Loss D: -0.0219
# Epoch 5, Loss G: 1.0889, Loss D: -0.0722
# Epoch 6, Loss G: 1.0656, Loss D: -0.0711
# Epoch 7, Loss G: 1.0035, Loss D: -0.0128
# Epoch 8, Loss G: 0.9336, Loss D: -0.1047
# Epoch 9, Loss G: 0.8466, Loss D: -0.0165
# Epoch 10, Loss G: 0.7886, Loss D: -0.0860
# Epoch 11, Loss G: 0.6601, Loss D: -0.0061
# Epoch 12, Loss G: 0.6222, Loss D: -0.0055
# Epoch 13, Loss G: 0.5008, Loss D: 0.1091
# Epoch 14, Loss G: 0.4767, Loss D: 0.1337
# Epoch 15, Loss G: 0.2825, Loss D: -0.0081
# Epoch 16, Loss G: 0.3230, Loss D: 0.1154
# Epoch 17, Loss G: 0.3441, Loss D: 0.0629
# Epoch 18, Loss G: 0.3011, Loss D: 0.1181
# Epoch 19, Loss G: 0.2116, Loss D: 0.1240
# Epoch 20, Loss G: 0.2060, Loss D: 0.0757
# Epoch 21, Loss G: 0.1986, Loss D: 0.0912
# Epoch 22, Loss G: 0.1506, Loss D: 0.0791
# Epoch 23, Loss G: 0.2001, Loss D: 0.0882
# Epoch 24, Loss G: 0.1865, Loss D: 0.0746
# Epoch 25, Loss G: 0.2699, Loss D: 0.1845
# Epoch 26, Loss G: 0.2613, Loss D: -0.0113
# Epoch 27, Loss G: 0.2806, Loss D: -0.0612
# Epoch 28, Loss G: 0.2943, Loss D: 0.0727
# Epoch 29, Loss G: 0.4414, Loss D: -0.0721
# Epoch 30, Loss G: 0.4130, Loss D: -0.0954
# Epoch 31, Loss G: 0.3876, Loss D: -0.1236
# Epoch 32, Loss G: 0.3185, Loss D: -0.0646
# Epoch 33, Loss G: 0.3476, Loss D: -0.0679
# Epoch 34, Loss G: 0.2996, Loss D: -0.1481
# Epoch 35, Loss G: 0.1912, Loss D: -0.0323
# Epoch 36, Loss G: 0.2109, Loss D: 0.1527
# Epoch 37, Loss G: 0.2192, Loss D: 0.0222
# Epoch 38, Loss G: 0.1574, Loss D: -0.0337
# Epoch 39, Loss G: 0.1671, Loss D: -0.0341
# Epoch 40, Loss G: 0.2272, Loss D: -0.1267
# Epoch 41, Loss G: 0.1723, Loss D: -0.0534
# Epoch 42, Loss G: 0.2640, Loss D: -0.0860
# Epoch 43, Loss G: 0.1943, Loss D: -0.1396
# Epoch 44, Loss G: 0.1647, Loss D: -0.1539
# Epoch 45, Loss G: 0.2629, Loss D: -0.2494
# Epoch 46, Loss G: 0.0858, Loss D: 0.0215
# Epoch 47, Loss G: 0.0666, Loss D: -0.0436
# Epoch 48, Loss G: -0.0734, Loss D: 0.1953
# Epoch 49, Loss G: -0.1486, Loss D: 0.0496
# Epoch 50, Loss G: -0.2413, Loss D: 0.1656
# Epoch 51, Loss G: -0.3436, Loss D: 0.1547
# Epoch 52, Loss G: -0.4450, Loss D: 0.1067
# Epoch 53, Loss G: -0.3721, Loss D: 0.1539
# Epoch 54, Loss G: -0.4007, Loss D: 0.2314
# Epoch 55, Loss G: -0.4260, Loss D: 0.3181
# Epoch 56, Loss G: -0.4805, Loss D: 0.1384
# Epoch 57, Loss G: -0.4578, Loss D: -0.0230
# Epoch 58, Loss G: -0.4522, Loss D: 0.1200
# Epoch 59, Loss G: -0.4463, Loss D: 0.2038
# Epoch 60, Loss G: -0.5079, Loss D: -0.0544
# Epoch 61, Loss G: -0.4449, Loss D: 0.1261
# Epoch 62, Loss G: -0.6198, Loss D: 0.1088
# Epoch 63, Loss G: -0.6267, Loss D: 0.0863
# Epoch 64, Loss G: -0.7634, Loss D: 0.1093
# Epoch 65, Loss G: -0.8817, Loss D: 0.1134
# Epoch 66, Loss G: -0.9075, Loss D: 0.1119
# Epoch 67, Loss G: -0.8884, Loss D: 0.1120
# Epoch 68, Loss G: -0.8731, Loss D: 0.1419
# Epoch 69, Loss G: -0.8099, Loss D: 0.1069
# Epoch 70, Loss G: -0.7226, Loss D: -0.0001
# Epoch 71, Loss G: -0.6146, Loss D: -0.0964
# Epoch 72, Loss G: -0.6796, Loss D: -0.2790
# Epoch 73, Loss G: -0.7079, Loss D: -0.0959
# Epoch 74, Loss G: -0.7522, Loss D: -0.2093
# Epoch 75, Loss G: -0.8071, Loss D: -0.0818
# Epoch 76, Loss G: -0.7721, Loss D: -0.0363
# Epoch 77, Loss G: -0.9217, Loss D: 0.0271
# Epoch 78, Loss G: -0.9553, Loss D: 0.1062
# Epoch 79, Loss G: -1.1173, Loss D: 0.1219
# Epoch 80, Loss G: -1.0937, Loss D: 0.1406
# Epoch 81, Loss G: -1.1814, Loss D: 0.2307
# Epoch 82, Loss G: -1.1686, Loss D: 0.1839
# Epoch 83, Loss G: -1.2145, Loss D: 0.1197
# Epoch 84, Loss G: -1.2406, Loss D: 0.1469
# Epoch 85, Loss G: -1.1469, Loss D: 0.2753
# Epoch 86, Loss G: -1.1938, Loss D: 0.1016
# Epoch 87, Loss G: -1.0801, Loss D: 0.1412
# Epoch 88, Loss G: -1.0701, Loss D: 0.0555
# Epoch 89, Loss G: -1.0929, Loss D: 0.0606
# Epoch 90, Loss G: -1.0334, Loss D: -0.0719
# Epoch 91, Loss G: -1.0696, Loss D: 0.1134
# Epoch 92, Loss G: -1.0864, Loss D: 0.0607
# Epoch 93, Loss G: -1.0062, Loss D: 0.0677
# Epoch 94, Loss G: -1.1241, Loss D: -0.1224
# Epoch 95, Loss G: -1.0000, Loss D: 0.0299
# Epoch 96, Loss G: -1.0100, Loss D: -0.0698
# Epoch 97, Loss G: -1.0300, Loss D: -0.2018
# Epoch 98, Loss G: -1.0075, Loss D: -0.0177
# Epoch 99, Loss G: -1.0150, Loss D: 0.0672
# Epoch 100, Loss G: -0.9146, Loss D: -0.0906
# Epoch 101, Loss G: -0.9930, Loss D: -0.0272
# Epoch 102, Loss G: -1.1295, Loss D: -0.1084
# Epoch 103, Loss G: -0.9991, Loss D: -0.0609
# Epoch 104, Loss G: -1.0728, Loss D: -0.0268
# Epoch 105, Loss G: -1.1256, Loss D: 0.0967
# Epoch 106, Loss G: -1.0856, Loss D: 0.0280
# Epoch 107, Loss G: -1.1413, Loss D: -0.0445
# Epoch 108, Loss G: -1.1938, Loss D: -0.0304
# Epoch 109, Loss G: -1.1584, Loss D: 0.0081
# Epoch 110, Loss G: -1.0392, Loss D: -0.0238
# Epoch 111, Loss G: -1.1907, Loss D: 0.0024
# Epoch 112, Loss G: -1.3053, Loss D: -0.0224
# Epoch 113, Loss G: -1.2712, Loss D: 0.0672
# Epoch 114, Loss G: -1.4166, Loss D: 0.0446
# Epoch 115, Loss G: -1.4233, Loss D: 0.0740
# Epoch 116, Loss G: -1.3915, Loss D: 0.1810
# Epoch 117, Loss G: -1.4831, Loss D: 0.0504
# Epoch 118, Loss G: -1.3271, Loss D: 0.0564
# Epoch 119, Loss G: -1.3911, Loss D: 0.0509
# Epoch 120, Loss G: -1.2280, Loss D: -0.0486
# Epoch 121, Loss G: -1.2482, Loss D: -0.1412
# Epoch 122, Loss G: -1.2106, Loss D: -0.2082
# Epoch 123, Loss G: -1.3117, Loss D: -0.0625
# Epoch 124, Loss G: -1.3590, Loss D: -0.0364
# Epoch 125, Loss G: -1.4073, Loss D: -0.0522
# Epoch 126, Loss G: -1.4150, Loss D: 0.1551
# Epoch 127, Loss G: -1.4985, Loss D: 0.0669
# Epoch 128, Loss G: -1.5492, Loss D: -0.1355
# Epoch 129, Loss G: -1.4348, Loss D: -0.0533
# Epoch 130, Loss G: -1.3738, Loss D: -0.0467
# Epoch 131, Loss G: -1.3493, Loss D: -0.1492
# Epoch 132, Loss G: -1.3527, Loss D: -0.0702
# Epoch 133, Loss G: -1.2714, Loss D: -0.0339
# Epoch 134, Loss G: -1.3687, Loss D: -0.1718
# Epoch 135, Loss G: -1.4814, Loss D: -0.0397
# Epoch 136, Loss G: -1.5778, Loss D: 0.0780
# Epoch 137, Loss G: -1.6292, Loss D: 0.2330
# Epoch 138, Loss G: -1.7217, Loss D: 0.1989
# Epoch 139, Loss G: -1.6916, Loss D: 0.2202
# Epoch 140, Loss G: -1.6436, Loss D: 0.0789
# Epoch 141, Loss G: -1.6480, Loss D: 0.1969
# Epoch 142, Loss G: -1.5555, Loss D: -0.1572
# Epoch 143, Loss G: -1.4165, Loss D: -0.0189
# Epoch 144, Loss G: -1.4891, Loss D: 0.0156
# Epoch 145, Loss G: -1.4537, Loss D: 0.1269
# Epoch 146, Loss G: -1.5484, Loss D: 0.0286
# Epoch 147, Loss G: -1.6010, Loss D: 0.0729
# Epoch 148, Loss G: -1.6009, Loss D: 0.0884
# Epoch 149, Loss G: -1.5330, Loss D: -0.0106
# Epoch 150, Loss G: -1.5142, Loss D: -0.0046
# Epoch 151, Loss G: -1.4443, Loss D: -0.0191
# Epoch 152, Loss G: -1.5340, Loss D: -0.0514
# Epoch 153, Loss G: -1.5522, Loss D: 0.0190
# Epoch 154, Loss G: -1.4025, Loss D: 0.0440
# Epoch 155, Loss G: -1.4925, Loss D: -0.1765
# Epoch 156, Loss G: -1.5420, Loss D: -0.0016
# Epoch 157, Loss G: -1.5809, Loss D: 0.0051
# Epoch 158, Loss G: -1.5622, Loss D: -0.0094
# Epoch 159, Loss G: -1.5937, Loss D: 0.0199
# Epoch 160, Loss G: -1.3892, Loss D: 0.0568
# Epoch 161, Loss G: -1.5047, Loss D: 0.0209
# Epoch 162, Loss G: -1.5427, Loss D: 0.0409
# Epoch 163, Loss G: -1.6249, Loss D: 0.0810
# Epoch 164, Loss G: -1.6550, Loss D: 0.0229
# Epoch 165, Loss G: -1.7133, Loss D: 0.1521
# Epoch 166, Loss G: -1.7002, Loss D: 0.1478
# Epoch 167, Loss G: -1.6055, Loss D: -0.0244
# Epoch 168, Loss G: -1.5744, Loss D: 0.0210
# Epoch 169, Loss G: -1.5233, Loss D: -0.0814
# Epoch 170, Loss G: -1.4863, Loss D: -0.0803
# Epoch 171, Loss G: -1.5046, Loss D: -0.0326
# Epoch 172, Loss G: -1.4739, Loss D: -0.0927
# Epoch 173, Loss G: -1.5748, Loss D: -0.1083
# Epoch 174, Loss G: -1.5927, Loss D: -0.1149
# Epoch 175, Loss G: -1.5559, Loss D: -0.0858
# Epoch 176, Loss G: -1.6503, Loss D: 0.0101
# Epoch 177, Loss G: -1.6747, Loss D: -0.0013
# Epoch 178, Loss G: -1.7167, Loss D: 0.1088
# Epoch 179, Loss G: -1.7362, Loss D: 0.0445
# Epoch 180, Loss G: -1.7487, Loss D: 0.1402
# Epoch 181, Loss G: -1.7311, Loss D: 0.0726
# Epoch 182, Loss G: -1.7263, Loss D: 0.1031
# Epoch 183, Loss G: -1.6078, Loss D: 0.0104
# Epoch 184, Loss G: -1.5228, Loss D: 0.1205
# Epoch 185, Loss G: -1.6347, Loss D: -0.0670
# Epoch 186, Loss G: -1.5931, Loss D: 0.1430
# Epoch 187, Loss G: -1.6668, Loss D: -0.0349
# Epoch 188, Loss G: -1.5746, Loss D: -0.0491
# Epoch 189, Loss G: -1.6357, Loss D: 0.0746
# Epoch 190, Loss G: -1.7052, Loss D: 0.0636
# Epoch 191, Loss G: -1.5833, Loss D: 0.0758
# Epoch 192, Loss G: -1.6053, Loss D: -0.0380
# Epoch 193, Loss G: -1.5904, Loss D: -0.0918
# Epoch 194, Loss G: -1.5256, Loss D: -0.0832
# Epoch 195, Loss G: -1.6545, Loss D: -0.1707
# Epoch 196, Loss G: -1.5661, Loss D: -0.0129
# Epoch 197, Loss G: -1.6548, Loss D: -0.1090
# Epoch 198, Loss G: -1.7725, Loss D: 0.0319
# Epoch 199, Loss G: -1.8013, Loss D: -0.0044
# Epoch 200, Loss G: -1.7854, Loss D: 0.0457
# Epoch 201, Loss G: -1.9169, Loss D: 0.1026
# Epoch 202, Loss G: -1.9426, Loss D: 0.1881
# Epoch 203, Loss G: -1.8971, Loss D: -0.0393
# Epoch 204, Loss G: -1.8845, Loss D: 0.0922
# Epoch 205, Loss G: -1.7652, Loss D: -0.0652
# Epoch 206, Loss G: -1.8512, Loss D: -0.2029
# Epoch 207, Loss G: -1.8676, Loss D: -0.1299
# Epoch 208, Loss G: -1.8355, Loss D: -0.0607
# Epoch 209, Loss G: -1.9044, Loss D: 0.0003
# Epoch 210, Loss G: -1.9819, Loss D: -0.1017
# Epoch 211, Loss G: -1.9955, Loss D: 0.1515
# Epoch 212, Loss G: -1.9747, Loss D: 0.0324
# Epoch 213, Loss G: -2.1306, Loss D: 0.2104
# Epoch 214, Loss G: -1.9408, Loss D: 0.2679
# Epoch 215, Loss G: -2.1413, Loss D: 0.2402
# Epoch 216, Loss G: -1.9809, Loss D: 0.2257
# Epoch 217, Loss G: -2.0226, Loss D: 0.0820
# Epoch 218, Loss G: -1.9503, Loss D: 0.0994
# Epoch 219, Loss G: -1.8176, Loss D: -0.2218
# Epoch 220, Loss G: -1.8066, Loss D: -0.0333
# Epoch 221, Loss G: -1.7210, Loss D: -0.1739
# Epoch 222, Loss G: -1.6482, Loss D: -0.2705
# Epoch 223, Loss G: -1.6711, Loss D: -0.2858
# Epoch 224, Loss G: -1.5599, Loss D: -0.2668
# Epoch 225, Loss G: -1.6614, Loss D: -0.1728
# Epoch 226, Loss G: -1.7064, Loss D: -0.0340
# Epoch 227, Loss G: -1.8200, Loss D: 0.0614
# Epoch 228, Loss G: -1.7744, Loss D: 0.0562
# Epoch 229, Loss G: -1.9164, Loss D: 0.2099
# Epoch 230, Loss G: -1.7476, Loss D: 0.0824
# Epoch 231, Loss G: -1.7858, Loss D: 0.0669
# Epoch 232, Loss G: -1.8629, Loss D: 0.0218
# Epoch 233, Loss G: -1.8207, Loss D: 0.1246
# Epoch 234, Loss G: -1.6941, Loss D: 0.0078
# Epoch 235, Loss G: -1.6821, Loss D: -0.0496
# Epoch 236, Loss G: -1.7082, Loss D: 0.0377
# Epoch 237, Loss G: -1.7705, Loss D: -0.0236
# Epoch 238, Loss G: -1.8000, Loss D: 0.0276
# Epoch 239, Loss G: -1.8270, Loss D: 0.0239
# Epoch 240, Loss G: -1.7465, Loss D: 0.0964
# Epoch 241, Loss G: -1.8804, Loss D: -0.0009
# Epoch 242, Loss G: -1.8340, Loss D: -0.1595
# Epoch 243, Loss G: -1.7108, Loss D: -0.1320
# Epoch 244, Loss G: -1.7884, Loss D: -0.0973
# Epoch 245, Loss G: -1.7234, Loss D: -0.1080
# Epoch 246, Loss G: -1.6716, Loss D: -0.2227
# Epoch 247, Loss G: -1.7028, Loss D: -0.1014
# Epoch 248, Loss G: -1.6493, Loss D: -0.1602
# Epoch 249, Loss G: -1.7285, Loss D: -0.1316
# Epoch 250, Loss G: -1.8960, Loss D: -0.0051
# Epoch 251, Loss G: -1.7590, Loss D: -0.0176
# Epoch 252, Loss G: -1.9320, Loss D: 0.0527
# Epoch 253, Loss G: -1.9180, Loss D: 0.0328
# Epoch 254, Loss G: -1.9119, Loss D: 0.2475
# Epoch 255, Loss G: -2.0374, Loss D: 0.1499
# Epoch 256, Loss G: -1.9809, Loss D: 0.0838
# Epoch 257, Loss G: -1.9550, Loss D: 0.0028
# Epoch 258, Loss G: -1.9594, Loss D: 0.1411
# Epoch 259, Loss G: -1.8885, Loss D: -0.1111
# Epoch 260, Loss G: -1.8175, Loss D: -0.0933
# Epoch 261, Loss G: -1.8689, Loss D: -0.0492
# Epoch 262, Loss G: -1.8705, Loss D: -0.0856
# Epoch 263, Loss G: -1.7762, Loss D: -0.0456
# Epoch 264, Loss G: -1.6802, Loss D: -0.1655
# Epoch 265, Loss G: -1.8010, Loss D: -0.1645
# Epoch 266, Loss G: -1.5671, Loss D: -0.2764
# Epoch 267, Loss G: -1.6131, Loss D: -0.1461
# Epoch 268, Loss G: -1.6110, Loss D: -0.1361
# Epoch 269, Loss G: -1.6140, Loss D: -0.2316
# Epoch 270, Loss G: -1.6859, Loss D: 0.0209
# Epoch 271, Loss G: -1.6330, Loss D: -0.1037
# Epoch 272, Loss G: -1.7492, Loss D: -0.0060
# Epoch 273, Loss G: -1.8595, Loss D: -0.0598
# Epoch 274, Loss G: -1.8435, Loss D: 0.1155
# Epoch 275, Loss G: -1.8801, Loss D: 0.0711
# Epoch 276, Loss G: -1.7828, Loss D: 0.0459
# Epoch 277, Loss G: -1.8517, Loss D: 0.0502
# Epoch 278, Loss G: -1.7343, Loss D: 0.0138
# Epoch 279, Loss G: -1.8932, Loss D: 0.0049
# Epoch 280, Loss G: -1.8089, Loss D: -0.0599
# Epoch 281, Loss G: -1.7499, Loss D: -0.0825
# Epoch 282, Loss G: -1.8379, Loss D: -0.0713
# Epoch 283, Loss G: -1.7485, Loss D: -0.1646
# Epoch 284, Loss G: -1.6665, Loss D: -0.2776
# Epoch 285, Loss G: -1.6667, Loss D: -0.0676
# Epoch 286, Loss G: -1.6063, Loss D: 0.0186
# Epoch 287, Loss G: -1.7854, Loss D: -0.0004
# Epoch 288, Loss G: -1.7307, Loss D: 0.0249
# Epoch 289, Loss G: -1.7398, Loss D: 0.0878
# Epoch 290, Loss G: -1.6069, Loss D: -0.0140
# Epoch 291, Loss G: -1.6351, Loss D: -0.0824
# Epoch 292, Loss G: -1.7206, Loss D: -0.0851
# Epoch 293, Loss G: -1.6667, Loss D: -0.0024
# Epoch 294, Loss G: -1.7912, Loss D: 0.0231
# Epoch 295, Loss G: -1.7125, Loss D: 0.0873
# Epoch 296, Loss G: -1.7250, Loss D: 0.1330
# Epoch 297, Loss G: -1.7684, Loss D: -0.0629
# Epoch 298, Loss G: -1.8047, Loss D: -0.0026
# Epoch 299, Loss G: -1.7197, Loss D: 0.0125
# Epoch 300, Loss G: -1.7190, Loss D: 0.1006

# %% [markdown]
# ## ASHRAE
# Required samples
#
# | Model  | -3 | -2 | -1 | 0 | 1 | 2 | 3 |
# |--------|----|----|----|---|---|---|---|
# | SMOTE  | 17894 | 16287 | 11695 | 0 | 10161 | 14096 | 16173 |
# | ADASYN | 18159 | 16619 | 12065 | 0 | 10987 | 14974 | 16971 |

# %%
discrete_columns_ashrae = [
    'Thermal sensation rounded'
]

ctgan_ashrae = CTGANSynthesizer()
ctgan_ashrae.fit(df_ashrae_train, discrete_columns_ashrae, epochs=600) #epochs=300
save_pickle(ctgan_ashrae, "models/ctgan_ashrae.pkl")
# Out:
# Epoch 1, Loss G: 0.6192, Loss D: 0.3329
# Epoch 2, Loss G: -0.1899, Loss D: 0.1287
# Epoch 3, Loss G: -0.9032, Loss D: -0.0536
# Epoch 4, Loss G: -1.1570, Loss D: 0.0847
# Epoch 5, Loss G: -1.3507, Loss D: 0.0044
# Epoch 6, Loss G: -1.5600, Loss D: -0.0220
# Epoch 7, Loss G: -1.6640, Loss D: -0.0038
# Epoch 8, Loss G: -1.6458, Loss D: -0.0449
# Epoch 9, Loss G: -1.6058, Loss D: 0.0456
# Epoch 10, Loss G: -1.8149, Loss D: 0.0502
# Epoch 11, Loss G: -1.7369, Loss D: -0.0242
# Epoch 12, Loss G: -1.8675, Loss D: -0.0535
# Epoch 13, Loss G: -1.7964, Loss D: -0.0773
# Epoch 14, Loss G: -1.8895, Loss D: -0.0081
# Epoch 15, Loss G: -1.8853, Loss D: -0.0656
# Epoch 16, Loss G: -1.9387, Loss D: 0.0852
# Epoch 17, Loss G: -1.9157, Loss D: -0.0237
# Epoch 18, Loss G: -1.9925, Loss D: 0.0045
# Epoch 19, Loss G: -1.9595, Loss D: 0.0384
# Epoch 20, Loss G: -1.9388, Loss D: 0.0879
# Epoch 21, Loss G: -2.0491, Loss D: -0.0159
# Epoch 22, Loss G: -2.0937, Loss D: -0.0421
# Epoch 23, Loss G: -2.1109, Loss D: -0.0616
# Epoch 24, Loss G: -1.9906, Loss D: -0.1110
# Epoch 25, Loss G: -2.0729, Loss D: -0.0393
# Epoch 26, Loss G: -2.1254, Loss D: 0.1426
# Epoch 27, Loss G: -2.0693, Loss D: 0.0500
# Epoch 28, Loss G: -2.1157, Loss D: -0.0382
# Epoch 29, Loss G: -2.1294, Loss D: -0.0017
# Epoch 30, Loss G: -2.1262, Loss D: -0.0336
# Epoch 31, Loss G: -2.1013, Loss D: -0.0199
# Epoch 32, Loss G: -2.1135, Loss D: 0.0124
# Epoch 33, Loss G: -2.0869, Loss D: 0.0290
# Epoch 34, Loss G: -2.1080, Loss D: -0.0531
# Epoch 35, Loss G: -2.0489, Loss D: -0.0149
# Epoch 36, Loss G: -2.1098, Loss D: -0.0334
# Epoch 37, Loss G: -2.0934, Loss D: 0.0195
# Epoch 38, Loss G: -2.1794, Loss D: -0.0366
# Epoch 39, Loss G: -2.1860, Loss D: -0.0394
# Epoch 40, Loss G: -2.1752, Loss D: -0.0671
# Epoch 41, Loss G: -2.2942, Loss D: 0.0441
# Epoch 42, Loss G: -2.2947, Loss D: 0.0264
# Epoch 43, Loss G: -2.1922, Loss D: 0.0695
# Epoch 44, Loss G: -2.2884, Loss D: -0.0948
# Epoch 45, Loss G: -2.2258, Loss D: -0.0262
# Epoch 46, Loss G: -2.1461, Loss D: -0.0469
# Epoch 47, Loss G: -2.1966, Loss D: -0.0297
# Epoch 48, Loss G: -2.2035, Loss D: -0.0091
# Epoch 49, Loss G: -2.2854, Loss D: 0.0270
# Epoch 50, Loss G: -2.1966, Loss D: 0.0651
# Epoch 51, Loss G: -2.2228, Loss D: 0.0102
# Epoch 52, Loss G: -2.2057, Loss D: 0.0068
# Epoch 53, Loss G: -2.2206, Loss D: -0.0667
# Epoch 54, Loss G: -2.0926, Loss D: -0.0745
# Epoch 55, Loss G: -2.2210, Loss D: -0.1421
# Epoch 56, Loss G: -2.3276, Loss D: -0.0661
# Epoch 57, Loss G: -2.1830, Loss D: -0.0076
# Epoch 58, Loss G: -2.1919, Loss D: -0.0569
# Epoch 59, Loss G: -2.1255, Loss D: -0.0403
# Epoch 60, Loss G: -2.2457, Loss D: -0.0429
# Epoch 61, Loss G: -2.2845, Loss D: 0.0491
# Epoch 62, Loss G: -2.1657, Loss D: -0.0221
# Epoch 63, Loss G: -2.2312, Loss D: 0.0496
# Epoch 64, Loss G: -2.1446, Loss D: -0.0349
# Epoch 65, Loss G: -2.1701, Loss D: 0.0282
# Epoch 66, Loss G: -2.2258, Loss D: -0.0275
# Epoch 67, Loss G: -2.1421, Loss D: -0.0841
# Epoch 68, Loss G: -2.2224, Loss D: -0.0070
# Epoch 69, Loss G: -2.1792, Loss D: 0.0065
# Epoch 70, Loss G: -2.1862, Loss D: -0.0309
# Epoch 71, Loss G: -2.2011, Loss D: -0.0081
# Epoch 72, Loss G: -2.1970, Loss D: 0.0197
# Epoch 73, Loss G: -2.1552, Loss D: -0.0536
# Epoch 74, Loss G: -2.2586, Loss D: -0.0326
# Epoch 75, Loss G: -2.2648, Loss D: 0.0001
# Epoch 76, Loss G: -2.3085, Loss D: -0.0004
# Epoch 77, Loss G: -2.1466, Loss D: -0.0096
# Epoch 78, Loss G: -2.2941, Loss D: 0.0352
# Epoch 79, Loss G: -2.3120, Loss D: -0.0251
# Epoch 80, Loss G: -2.2505, Loss D: 0.0285
# Epoch 81, Loss G: -2.3156, Loss D: 0.0028
# Epoch 82, Loss G: -2.3860, Loss D: 0.0039
# Epoch 83, Loss G: -2.2191, Loss D: 0.0232
# Epoch 84, Loss G: -2.2578, Loss D: -0.0500
# Epoch 85, Loss G: -2.1424, Loss D: 0.0198
# Epoch 86, Loss G: -2.1574, Loss D: 0.0462
# Epoch 87, Loss G: -2.3159, Loss D: -0.0498
# Epoch 88, Loss G: -2.2367, Loss D: 0.0614
# Epoch 89, Loss G: -2.2577, Loss D: 0.0517
# Epoch 90, Loss G: -2.1826, Loss D: -0.0812
# Epoch 91, Loss G: -2.3188, Loss D: 0.0357
# Epoch 92, Loss G: -2.2025, Loss D: 0.0827
# Epoch 93, Loss G: -2.3136, Loss D: 0.0309
# Epoch 94, Loss G: -2.2094, Loss D: -0.0705
# Epoch 95, Loss G: -2.2949, Loss D: 0.0372
# Epoch 96, Loss G: -2.3967, Loss D: -0.0134
# Epoch 97, Loss G: -2.2648, Loss D: -0.0131
# Epoch 98, Loss G: -2.1877, Loss D: 0.0368
# Epoch 99, Loss G: -2.2249, Loss D: 0.0090
# Epoch 100, Loss G: -2.1871, Loss D: -0.0026
# Epoch 101, Loss G: -2.3265, Loss D: -0.0071
# Epoch 102, Loss G: -2.2643, Loss D: -0.0643
# Epoch 103, Loss G: -2.2697, Loss D: -0.0328
# Epoch 104, Loss G: -2.3473, Loss D: 0.0064
# Epoch 105, Loss G: -2.2143, Loss D: 0.0061
# Epoch 106, Loss G: -2.3257, Loss D: -0.0083
# Epoch 107, Loss G: -2.3157, Loss D: -0.1135
# Epoch 108, Loss G: -2.3338, Loss D: -0.0681
# Epoch 109, Loss G: -2.2930, Loss D: 0.0793
# Epoch 110, Loss G: -2.3544, Loss D: -0.0007
# Epoch 111, Loss G: -2.2894, Loss D: 0.0155
# Epoch 112, Loss G: -2.2665, Loss D: 0.0740
# Epoch 113, Loss G: -2.1620, Loss D: -0.0386
# Epoch 114, Loss G: -2.2293, Loss D: 0.0977
# Epoch 115, Loss G: -2.2992, Loss D: 0.0404
# Epoch 116, Loss G: -2.2272, Loss D: -0.0555
# Epoch 117, Loss G: -2.3675, Loss D: -0.0170
# Epoch 118, Loss G: -2.3322, Loss D: 0.0524
# Epoch 119, Loss G: -2.2466, Loss D: -0.0211
# Epoch 120, Loss G: -2.2497, Loss D: -0.0526
# Epoch 121, Loss G: -2.3039, Loss D: 0.0233
# Epoch 122, Loss G: -2.2968, Loss D: 0.0208
# Epoch 123, Loss G: -2.3012, Loss D: 0.0258
# Epoch 124, Loss G: -2.3611, Loss D: 0.0479
# Epoch 125, Loss G: -2.2432, Loss D: 0.0873
# Epoch 126, Loss G: -2.2284, Loss D: -0.0260
# Epoch 127, Loss G: -2.2836, Loss D: -0.0257
# Epoch 128, Loss G: -2.1672, Loss D: -0.0645
# Epoch 129, Loss G: -2.3080, Loss D: 0.0399
# Epoch 130, Loss G: -2.2873, Loss D: 0.0401
# Epoch 131, Loss G: -2.2918, Loss D: 0.0434
# Epoch 132, Loss G: -2.3012, Loss D: 0.0083
# Epoch 133, Loss G: -2.3603, Loss D: -0.0407
# Epoch 134, Loss G: -2.2994, Loss D: 0.0856
# Epoch 135, Loss G: -2.3328, Loss D: -0.0465
# Epoch 136, Loss G: -2.2676, Loss D: -0.0619
# Epoch 137, Loss G: -2.3047, Loss D: -0.0204
# Epoch 138, Loss G: -2.2816, Loss D: -0.0276
# Epoch 139, Loss G: -2.3189, Loss D: -0.0586
# Epoch 140, Loss G: -2.2638, Loss D: 0.0758
# Epoch 141, Loss G: -2.2987, Loss D: -0.0122
# Epoch 142, Loss G: -2.4303, Loss D: 0.0519
# Epoch 143, Loss G: -2.3521, Loss D: -0.0964
# Epoch 144, Loss G: -2.4293, Loss D: 0.0464
# Epoch 145, Loss G: -2.2121, Loss D: 0.0603
# Epoch 146, Loss G: -2.3992, Loss D: 0.0869
# Epoch 147, Loss G: -2.3189, Loss D: 0.0295
# Epoch 148, Loss G: -2.3539, Loss D: 0.0555
# Epoch 149, Loss G: -2.3724, Loss D: -0.0356
# Epoch 150, Loss G: -2.3200, Loss D: 0.0034
# Epoch 151, Loss G: -2.3870, Loss D: -0.0152
# Epoch 152, Loss G: -2.3844, Loss D: 0.0482
# Epoch 153, Loss G: -2.2925, Loss D: 0.0141
# Epoch 154, Loss G: -2.2717, Loss D: 0.0260
# Epoch 155, Loss G: -2.2805, Loss D: 0.0046
# Epoch 156, Loss G: -2.3064, Loss D: 0.0273
# Epoch 157, Loss G: -2.3202, Loss D: 0.0862
# Epoch 158, Loss G: -2.2855, Loss D: 0.0530
# Epoch 159, Loss G: -2.3278, Loss D: 0.0992
# Epoch 160, Loss G: -2.2964, Loss D: 0.0044
# Epoch 161, Loss G: -2.3008, Loss D: 0.0067
# Epoch 162, Loss G: -2.2877, Loss D: -0.0517
# Epoch 163, Loss G: -2.3273, Loss D: 0.0414
# Epoch 164, Loss G: -2.4062, Loss D: -0.0526
# Epoch 165, Loss G: -2.3645, Loss D: 0.0173
# Epoch 166, Loss G: -2.3346, Loss D: -0.0029
# Epoch 167, Loss G: -2.3868, Loss D: -0.0246
# Epoch 168, Loss G: -2.2898, Loss D: -0.0398
# Epoch 169, Loss G: -2.3134, Loss D: -0.0204
# Epoch 170, Loss G: -2.4382, Loss D: -0.0096
# Epoch 171, Loss G: -2.3339, Loss D: -0.0018
# Epoch 172, Loss G: -2.3707, Loss D: -0.0538
# Epoch 173, Loss G: -2.3277, Loss D: 0.0853
# Epoch 174, Loss G: -2.2702, Loss D: -0.0786
# Epoch 175, Loss G: -2.3813, Loss D: -0.0291
# Epoch 176, Loss G: -2.3155, Loss D: -0.0348
# Epoch 177, Loss G: -2.2895, Loss D: -0.0157
# Epoch 178, Loss G: -2.3130, Loss D: -0.0508
# Epoch 179, Loss G: -2.3756, Loss D: -0.0279
# Epoch 180, Loss G: -2.3416, Loss D: 0.0701
# Epoch 181, Loss G: -2.4478, Loss D: 0.0607
# Epoch 182, Loss G: -2.4033, Loss D: -0.0259
# Epoch 183, Loss G: -2.3638, Loss D: 0.0328
# Epoch 184, Loss G: -2.2909, Loss D: -0.0605
# Epoch 185, Loss G: -2.3487, Loss D: 0.0196
# Epoch 186, Loss G: -2.3196, Loss D: 0.0351
# Epoch 187, Loss G: -2.2735, Loss D: 0.0712
# Epoch 188, Loss G: -2.2960, Loss D: -0.0138
# Epoch 189, Loss G: -2.3512, Loss D: 0.0043
# Epoch 190, Loss G: -2.3402, Loss D: 0.0752
# Epoch 191, Loss G: -2.2751, Loss D: -0.0350
# Epoch 192, Loss G: -2.3071, Loss D: -0.0046
# Epoch 193, Loss G: -2.3501, Loss D: -0.0495
# Epoch 194, Loss G: -2.2672, Loss D: 0.0826
# Epoch 195, Loss G: -2.3288, Loss D: -0.0286
# Epoch 196, Loss G: -2.3503, Loss D: -0.0159
# Epoch 197, Loss G: -2.3431, Loss D: -0.0140
# Epoch 198, Loss G: -2.4066, Loss D: 0.0145
# Epoch 199, Loss G: -2.2835, Loss D: 0.0062
# Epoch 200, Loss G: -2.3310, Loss D: -0.0040
# Epoch 201, Loss G: -2.2990, Loss D: 0.0076
# Epoch 202, Loss G: -2.3971, Loss D: 0.0034
# Epoch 203, Loss G: -2.2547, Loss D: -0.0722
# Epoch 204, Loss G: -2.4240, Loss D: 0.0198
# Epoch 205, Loss G: -2.2783, Loss D: -0.0694
# Epoch 206, Loss G: -2.3951, Loss D: -0.0258
# Epoch 207, Loss G: -2.3104, Loss D: 0.0489
# Epoch 208, Loss G: -2.2664, Loss D: 0.0036
# Epoch 209, Loss G: -2.2808, Loss D: -0.1003
# Epoch 210, Loss G: -2.3251, Loss D: 0.0153
# Epoch 211, Loss G: -2.4819, Loss D: -0.0660
# Epoch 212, Loss G: -2.2101, Loss D: -0.0316
# Epoch 213, Loss G: -2.2936, Loss D: 0.0608
# Epoch 214, Loss G: -2.3706, Loss D: 0.0905
# Epoch 215, Loss G: -2.4097, Loss D: -0.0165
# Epoch 216, Loss G: -2.3305, Loss D: 0.0373
# Epoch 217, Loss G: -2.3785, Loss D: -0.0392
# Epoch 218, Loss G: -2.3708, Loss D: -0.0374
# Epoch 219, Loss G: -2.3252, Loss D: -0.0344
# Epoch 220, Loss G: -2.3388, Loss D: -0.0209
# Epoch 221, Loss G: -2.3684, Loss D: -0.0295
# Epoch 222, Loss G: -2.3280, Loss D: -0.0743
# Epoch 223, Loss G: -2.2557, Loss D: 0.0073
# Epoch 224, Loss G: -2.3006, Loss D: -0.0771
# Epoch 225, Loss G: -2.2825, Loss D: 0.0281
# Epoch 226, Loss G: -2.3722, Loss D: 0.0082
# Epoch 227, Loss G: -2.3598, Loss D: 0.0227
# Epoch 228, Loss G: -2.3851, Loss D: -0.0420
# Epoch 229, Loss G: -2.3451, Loss D: 0.0285
# Epoch 230, Loss G: -2.4232, Loss D: 0.0262
# Epoch 231, Loss G: -2.2990, Loss D: 0.0230
# Epoch 232, Loss G: -2.4499, Loss D: 0.0207
# Epoch 233, Loss G: -2.2740, Loss D: 0.0415
# Epoch 234, Loss G: -2.3878, Loss D: 0.0320
# Epoch 235, Loss G: -2.3588, Loss D: 0.0741
# Epoch 236, Loss G: -2.4055, Loss D: 0.0010
# Epoch 237, Loss G: -2.3585, Loss D: 0.0067
# Epoch 238, Loss G: -2.3672, Loss D: 0.0879
# Epoch 239, Loss G: -2.2855, Loss D: -0.0021
# Epoch 240, Loss G: -2.3926, Loss D: -0.0725
# Epoch 241, Loss G: -2.3895, Loss D: -0.0726
# Epoch 242, Loss G: -2.3457, Loss D: 0.0183
# Epoch 243, Loss G: -2.3889, Loss D: -0.0124
# Epoch 244, Loss G: -2.4057, Loss D: -0.0790
# Epoch 245, Loss G: -2.4088, Loss D: -0.1402
# Epoch 246, Loss G: -2.3346, Loss D: 0.0547
# Epoch 247, Loss G: -2.4914, Loss D: 0.0277
# Epoch 248, Loss G: -2.3708, Loss D: -0.0962
# Epoch 249, Loss G: -2.3411, Loss D: -0.0904
# Epoch 250, Loss G: -2.3761, Loss D: -0.0413
# Epoch 251, Loss G: -2.3392, Loss D: -0.0687
# Epoch 252, Loss G: -2.4296, Loss D: 0.0095
# Epoch 253, Loss G: -2.3051, Loss D: -0.0227
# Epoch 254, Loss G: -2.3263, Loss D: 0.0163
# Epoch 255, Loss G: -2.3886, Loss D: -0.0568
# Epoch 256, Loss G: -2.3212, Loss D: 0.0084
# Epoch 257, Loss G: -2.2647, Loss D: -0.0540
# Epoch 258, Loss G: -2.4679, Loss D: 0.0360
# Epoch 259, Loss G: -2.3830, Loss D: 0.0280
# Epoch 260, Loss G: -2.3690, Loss D: -0.0266
# Epoch 261, Loss G: -2.2951, Loss D: 0.1000
# Epoch 262, Loss G: -2.2518, Loss D: 0.0016
# Epoch 263, Loss G: -2.3757, Loss D: 0.0566
# Epoch 264, Loss G: -2.3910, Loss D: 0.0743
# Epoch 265, Loss G: -2.4297, Loss D: -0.0261
# Epoch 266, Loss G: -2.3918, Loss D: 0.0033
# Epoch 267, Loss G: -2.3681, Loss D: -0.0263
# Epoch 268, Loss G: -2.4024, Loss D: 0.0521
# Epoch 269, Loss G: -2.4268, Loss D: 0.0479
# Epoch 270, Loss G: -2.3299, Loss D: -0.0080
# Epoch 271, Loss G: -2.3397, Loss D: -0.0751
# Epoch 272, Loss G: -2.4028, Loss D: -0.0394
# Epoch 273, Loss G: -2.3879, Loss D: -0.0266
# Epoch 274, Loss G: -2.3046, Loss D: -0.0225
# Epoch 275, Loss G: -2.4198, Loss D: -0.0829
# Epoch 276, Loss G: -2.3971, Loss D: 0.0889
# Epoch 277, Loss G: -2.3944, Loss D: 0.0019
# Epoch 278, Loss G: -2.4103, Loss D: -0.1347
# Epoch 279, Loss G: -2.3155, Loss D: 0.1117
# Epoch 280, Loss G: -2.3978, Loss D: -0.0524
# Epoch 281, Loss G: -2.3648, Loss D: -0.0357
# Epoch 282, Loss G: -2.2889, Loss D: 0.0095
# Epoch 283, Loss G: -2.4119, Loss D: 0.0144
# Epoch 284, Loss G: -2.4476, Loss D: -0.0168
# Epoch 285, Loss G: -2.4286, Loss D: -0.0829
# Epoch 286, Loss G: -2.4124, Loss D: -0.0428
# Epoch 287, Loss G: -2.2943, Loss D: -0.0509
# Epoch 288, Loss G: -2.3232, Loss D: 0.0327
# Epoch 289, Loss G: -2.4919, Loss D: 0.0354
# Epoch 290, Loss G: -2.3191, Loss D: -0.0460
# Epoch 291, Loss G: -2.4272, Loss D: 0.0059
# Epoch 292, Loss G: -2.4312, Loss D: -0.0471
# Epoch 293, Loss G: -2.3546, Loss D: -0.0899
# Epoch 294, Loss G: -2.3241, Loss D: 0.0956
# Epoch 295, Loss G: -2.3736, Loss D: 0.0749
# Epoch 296, Loss G: -2.3231, Loss D: -0.0125
# Epoch 297, Loss G: -2.3177, Loss D: -0.0375
# Epoch 298, Loss G: -2.3406, Loss D: -0.0726
# Epoch 299, Loss G: -2.4015, Loss D: 0.0941
# Epoch 300, Loss G: -2.3186, Loss D: 0.0463
# Epoch 301, Loss G: -2.3053, Loss D: -0.0286
# Epoch 302, Loss G: -2.2649, Loss D: 0.0884
# Epoch 303, Loss G: -2.4522, Loss D: -0.0022
# Epoch 304, Loss G: -2.4103, Loss D: -0.0330
# Epoch 305, Loss G: -2.3553, Loss D: -0.0071
# Epoch 306, Loss G: -2.3274, Loss D: -0.0561
# Epoch 307, Loss G: -2.4561, Loss D: 0.0165
# Epoch 308, Loss G: -2.4412, Loss D: 0.1198
# Epoch 309, Loss G: -2.2805, Loss D: -0.0450
# Epoch 310, Loss G: -2.4661, Loss D: 0.0199
# Epoch 311, Loss G: -2.4421, Loss D: 0.0282
# Epoch 312, Loss G: -2.3608, Loss D: -0.0154
# Epoch 313, Loss G: -2.4532, Loss D: 0.0412
# Epoch 314, Loss G: -2.4057, Loss D: -0.0044
# Epoch 315, Loss G: -2.3853, Loss D: 0.0041
# Epoch 316, Loss G: -2.4754, Loss D: 0.0422
# Epoch 317, Loss G: -2.3907, Loss D: -0.0086
# Epoch 318, Loss G: -2.3714, Loss D: -0.0936
# Epoch 319, Loss G: -2.3021, Loss D: -0.0075
# Epoch 320, Loss G: -2.3813, Loss D: 0.0564
# Epoch 321, Loss G: -2.3674, Loss D: -0.0355
# Epoch 322, Loss G: -2.3953, Loss D: -0.0518
# Epoch 323, Loss G: -2.3722, Loss D: 0.0676
# Epoch 324, Loss G: -2.3427, Loss D: 0.0731
# Epoch 325, Loss G: -2.3365, Loss D: -0.0873
# Epoch 326, Loss G: -2.3727, Loss D: -0.0056
# Epoch 327, Loss G: -2.2935, Loss D: 0.0192
# Epoch 328, Loss G: -2.3967, Loss D: -0.0442
# Epoch 329, Loss G: -2.3002, Loss D: 0.0288
# Epoch 330, Loss G: -2.3535, Loss D: 0.0391
# Epoch 331, Loss G: -2.2925, Loss D: 0.0440
# Epoch 332, Loss G: -2.3435, Loss D: 0.0449
# Epoch 333, Loss G: -2.3994, Loss D: -0.0236
# Epoch 334, Loss G: -2.3944, Loss D: -0.0707
# Epoch 335, Loss G: -2.3763, Loss D: 0.0183
# Epoch 336, Loss G: -2.3929, Loss D: -0.0621
# Epoch 337, Loss G: -2.4173, Loss D: 0.0293
# Epoch 338, Loss G: -2.4149, Loss D: 0.0154
# Epoch 339, Loss G: -2.4076, Loss D: 0.0500
# Epoch 340, Loss G: -2.4407, Loss D: -0.0209
# Epoch 341, Loss G: -2.4164, Loss D: 0.0437
# Epoch 342, Loss G: -2.3782, Loss D: -0.0596
# Epoch 343, Loss G: -2.4519, Loss D: -0.0237
# Epoch 344, Loss G: -2.5416, Loss D: -0.0383
# Epoch 345, Loss G: -2.2407, Loss D: 0.0242
# Epoch 346, Loss G: -2.4145, Loss D: 0.0412
# Epoch 347, Loss G: -2.3762, Loss D: 0.0315
# Epoch 348, Loss G: -2.3115, Loss D: -0.0111
# Epoch 349, Loss G: -2.2501, Loss D: 0.0365
# Epoch 350, Loss G: -2.3069, Loss D: 0.0825
# Epoch 351, Loss G: -2.3167, Loss D: 0.0576
# Epoch 352, Loss G: -2.4704, Loss D: -0.0146
# Epoch 353, Loss G: -2.4541, Loss D: -0.0542
# Epoch 354, Loss G: -2.3635, Loss D: -0.0793
# Epoch 355, Loss G: -2.3447, Loss D: -0.0801
# Epoch 356, Loss G: -2.3735, Loss D: 0.0677
# Epoch 357, Loss G: -2.4511, Loss D: -0.1349
# Epoch 358, Loss G: -2.3546, Loss D: -0.0707
# Epoch 359, Loss G: -2.3573, Loss D: -0.0799
# Epoch 360, Loss G: -2.4485, Loss D: -0.0587
# Epoch 361, Loss G: -2.3334, Loss D: -0.0276
# Epoch 362, Loss G: -2.3825, Loss D: 0.0351
# Epoch 363, Loss G: -2.4519, Loss D: -0.0816
# Epoch 364, Loss G: -2.3368, Loss D: 0.0964
# Epoch 365, Loss G: -2.3255, Loss D: -0.0616
# Epoch 366, Loss G: -2.3764, Loss D: 0.0066
# Epoch 367, Loss G: -2.2762, Loss D: -0.0421
# Epoch 368, Loss G: -2.4170, Loss D: -0.0032
# Epoch 369, Loss G: -2.2747, Loss D: 0.0316
# Epoch 370, Loss G: -2.2912, Loss D: 0.0674
# Epoch 371, Loss G: -2.4233, Loss D: -0.0652
# Epoch 372, Loss G: -2.4965, Loss D: -0.0584
# Epoch 373, Loss G: -2.3279, Loss D: -0.0669
# Epoch 374, Loss G: -2.3486, Loss D: -0.0296
# Epoch 375, Loss G: -2.4684, Loss D: 0.0334
# Epoch 376, Loss G: -2.3437, Loss D: 0.0115
# Epoch 377, Loss G: -2.3502, Loss D: 0.0199
# Epoch 378, Loss G: -2.2690, Loss D: -0.0518
# Epoch 379, Loss G: -2.3280, Loss D: 0.0800
# Epoch 380, Loss G: -2.3449, Loss D: -0.0446
# Epoch 381, Loss G: -2.5069, Loss D: -0.0091
# Epoch 382, Loss G: -2.3737, Loss D: 0.0279
# Epoch 383, Loss G: -2.3516, Loss D: -0.0315
# Epoch 384, Loss G: -2.2846, Loss D: -0.0249
# Epoch 385, Loss G: -2.4186, Loss D: 0.0290
# Epoch 386, Loss G: -2.3786, Loss D: -0.0108
# Epoch 387, Loss G: -2.3332, Loss D: -0.0170
# Epoch 388, Loss G: -2.3496, Loss D: 0.0459
# Epoch 389, Loss G: -2.3995, Loss D: 0.0630
# Epoch 390, Loss G: -2.3737, Loss D: 0.0500
# Epoch 391, Loss G: -2.3381, Loss D: 0.0582
# Epoch 392, Loss G: -2.3696, Loss D: 0.1021
# Epoch 393, Loss G: -2.3299, Loss D: -0.0265
# Epoch 394, Loss G: -2.2115, Loss D: 0.0525
# Epoch 395, Loss G: -2.3556, Loss D: -0.0226
# Epoch 396, Loss G: -2.3231, Loss D: 0.0325
# Epoch 397, Loss G: -2.4402, Loss D: 0.0017
# Epoch 398, Loss G: -2.3802, Loss D: 0.0627
# Epoch 399, Loss G: -2.3603, Loss D: -0.0476
# Epoch 400, Loss G: -2.4013, Loss D: -0.0896
# Epoch 401, Loss G: -2.4408, Loss D: -0.0557
# Epoch 402, Loss G: -2.3568, Loss D: -0.0115
# Epoch 403, Loss G: -2.3483, Loss D: 0.0373
# Epoch 404, Loss G: -2.5741, Loss D: -0.0406
# Epoch 405, Loss G: -2.3743, Loss D: -0.0080
# Epoch 406, Loss G: -2.4636, Loss D: -0.0072
# Epoch 407, Loss G: -2.2922, Loss D: 0.0162
# Epoch 408, Loss G: -2.3315, Loss D: -0.0794
# Epoch 409, Loss G: -2.3720, Loss D: 0.0461
# Epoch 410, Loss G: -2.3594, Loss D: 0.0283
# Epoch 411, Loss G: -2.3999, Loss D: -0.0224
# Epoch 412, Loss G: -2.2680, Loss D: -0.0174
# Epoch 413, Loss G: -2.3842, Loss D: -0.0526
# Epoch 414, Loss G: -2.3268, Loss D: 0.0025
# Epoch 415, Loss G: -2.4412, Loss D: -0.0460
# Epoch 416, Loss G: -2.2758, Loss D: -0.0392
# Epoch 417, Loss G: -2.4150, Loss D: -0.0642
# Epoch 418, Loss G: -2.5026, Loss D: -0.0104
# Epoch 419, Loss G: -2.3954, Loss D: -0.0470
# Epoch 420, Loss G: -2.4852, Loss D: -0.1053
# Epoch 421, Loss G: -2.4517, Loss D: -0.0038
# Epoch 422, Loss G: -2.2865, Loss D: -0.0098
# Epoch 423, Loss G: -2.3379, Loss D: 0.0515
# Epoch 424, Loss G: -2.3536, Loss D: -0.0016
# Epoch 425, Loss G: -2.3233, Loss D: 0.0560
# Epoch 426, Loss G: -2.3811, Loss D: -0.0055
# Epoch 427, Loss G: -2.3861, Loss D: -0.0384
# Epoch 428, Loss G: -2.3782, Loss D: -0.0462
# Epoch 429, Loss G: -2.4652, Loss D: 0.0591
# Epoch 430, Loss G: -2.3353, Loss D: -0.0446
# Epoch 431, Loss G: -2.3839, Loss D: -0.0160
# Epoch 432, Loss G: -2.4728, Loss D: 0.0459
# Epoch 433, Loss G: -2.4197, Loss D: 0.0364
# Epoch 434, Loss G: -2.2878, Loss D: 0.0493
# Epoch 435, Loss G: -2.3145, Loss D: -0.0083
# Epoch 436, Loss G: -2.3885, Loss D: 0.0965
# Epoch 437, Loss G: -2.2802, Loss D: 0.0560
# Epoch 438, Loss G: -2.2923, Loss D: -0.1070
# Epoch 439, Loss G: -2.3041, Loss D: 0.1448
# Epoch 440, Loss G: -2.2677, Loss D: 0.0171
# Epoch 441, Loss G: -2.4745, Loss D: 0.0043
# Epoch 442, Loss G: -2.3840, Loss D: 0.0458
# Epoch 443, Loss G: -2.3825, Loss D: -0.0459
# Epoch 444, Loss G: -2.2812, Loss D: 0.0812
# Epoch 445, Loss G: -2.4323, Loss D: -0.0574
# Epoch 446, Loss G: -2.3586, Loss D: -0.1252
# Epoch 447, Loss G: -2.3897, Loss D: 0.0215
# Epoch 448, Loss G: -2.2925, Loss D: 0.0327
# Epoch 449, Loss G: -2.2564, Loss D: 0.1482
# Epoch 450, Loss G: -2.4046, Loss D: 0.0655
# Epoch 451, Loss G: -2.3391, Loss D: 0.0217
# Epoch 452, Loss G: -2.2798, Loss D: -0.0098
# Epoch 453, Loss G: -2.4746, Loss D: -0.0443
# Epoch 454, Loss G: -2.4429, Loss D: -0.0416
# Epoch 455, Loss G: -2.4679, Loss D: 0.0200
# Epoch 456, Loss G: -2.5054, Loss D: -0.0025
# Epoch 457, Loss G: -2.3579, Loss D: 0.0610
# Epoch 458, Loss G: -2.3485, Loss D: -0.0199
# Epoch 459, Loss G: -2.4744, Loss D: 0.0615
# Epoch 460, Loss G: -2.4302, Loss D: -0.0765
# Epoch 461, Loss G: -2.3385, Loss D: -0.0526
# Epoch 462, Loss G: -2.3938, Loss D: -0.0293
# Epoch 463, Loss G: -2.4246, Loss D: -0.0795
# Epoch 464, Loss G: -2.3364, Loss D: -0.0498
# Epoch 465, Loss G: -2.4128, Loss D: -0.0777
# Epoch 466, Loss G: -2.3900, Loss D: 0.0119
# Epoch 467, Loss G: -2.2574, Loss D: -0.0192
# Epoch 468, Loss G: -2.3774, Loss D: 0.0221
# Epoch 469, Loss G: -2.3516, Loss D: 0.0410
# Epoch 470, Loss G: -2.3051, Loss D: -0.0119
# Epoch 471, Loss G: -2.4910, Loss D: -0.0684
# Epoch 472, Loss G: -2.4147, Loss D: -0.0187
# Epoch 473, Loss G: -2.3853, Loss D: 0.0482
# Epoch 474, Loss G: -2.4004, Loss D: 0.0533
# Epoch 475, Loss G: -2.4292, Loss D: 0.0597
# Epoch 476, Loss G: -2.3816, Loss D: 0.0148
# Epoch 477, Loss G: -2.3388, Loss D: -0.0157
# Epoch 478, Loss G: -2.2662, Loss D: -0.0825
# Epoch 479, Loss G: -2.3303, Loss D: -0.0107
# Epoch 480, Loss G: -2.3925, Loss D: 0.0183
# Epoch 481, Loss G: -2.4898, Loss D: -0.0769
# Epoch 482, Loss G: -2.3971, Loss D: -0.0596
# Epoch 483, Loss G: -2.3611, Loss D: -0.0233
# Epoch 484, Loss G: -2.2908, Loss D: 0.0186
# Epoch 485, Loss G: -2.4140, Loss D: 0.0027
# Epoch 486, Loss G: -2.5043, Loss D: 0.0120
# Epoch 487, Loss G: -2.3841, Loss D: -0.0282
# Epoch 488, Loss G: -2.3721, Loss D: 0.0925
# Epoch 489, Loss G: -2.3628, Loss D: -0.0716
# Epoch 490, Loss G: -2.3831, Loss D: 0.0261
# Epoch 491, Loss G: -2.4157, Loss D: -0.0138
# Epoch 492, Loss G: -2.3874, Loss D: -0.0184
# Epoch 493, Loss G: -2.4239, Loss D: 0.1318
# Epoch 494, Loss G: -2.3437, Loss D: 0.0428
# Epoch 495, Loss G: -2.3977, Loss D: 0.0241
# Epoch 496, Loss G: -2.3313, Loss D: 0.0087
# Epoch 497, Loss G: -2.4341, Loss D: -0.0023
# Epoch 498, Loss G: -2.5807, Loss D: -0.1885
# Epoch 499, Loss G: -2.4108, Loss D: 0.0906
# Epoch 500, Loss G: -2.4450, Loss D: 0.0760
# Epoch 501, Loss G: -2.3859, Loss D: 0.0849
# Epoch 502, Loss G: -2.4134, Loss D: 0.0943
# Epoch 503, Loss G: -2.3391, Loss D: 0.0073
# Epoch 504, Loss G: -2.4801, Loss D: -0.0629
# Epoch 505, Loss G: -2.5097, Loss D: -0.0945
# Epoch 506, Loss G: -2.3839, Loss D: -0.0373
# Epoch 507, Loss G: -2.3834, Loss D: -0.0204
# Epoch 508, Loss G: -2.4590, Loss D: 0.0723
# Epoch 509, Loss G: -2.3191, Loss D: -0.0829
# Epoch 510, Loss G: -2.3456, Loss D: 0.0669
# Epoch 511, Loss G: -2.4017, Loss D: -0.0004
# Epoch 512, Loss G: -2.3526, Loss D: 0.0489
# Epoch 513, Loss G: -2.4047, Loss D: 0.0170
# Epoch 514, Loss G: -2.4265, Loss D: 0.0056
# Epoch 515, Loss G: -2.4592, Loss D: -0.0745
# Epoch 516, Loss G: -2.3656, Loss D: -0.0092
# Epoch 517, Loss G: -2.4294, Loss D: -0.0606
# Epoch 518, Loss G: -2.3896, Loss D: -0.0316
# Epoch 519, Loss G: -2.3746, Loss D: 0.0257
# Epoch 520, Loss G: -2.3899, Loss D: 0.0095
# Epoch 521, Loss G: -2.3341, Loss D: 0.0538
# Epoch 522, Loss G: -2.4247, Loss D: -0.0197
# Epoch 523, Loss G: -2.5206, Loss D: 0.0097
# Epoch 524, Loss G: -2.3288, Loss D: 0.0465
# Epoch 525, Loss G: -2.4331, Loss D: -0.0313
# Epoch 526, Loss G: -2.4855, Loss D: -0.0922
# Epoch 527, Loss G: -2.4030, Loss D: -0.0850
# Epoch 528, Loss G: -2.3835, Loss D: 0.0236
# Epoch 529, Loss G: -2.3995, Loss D: -0.0293
# Epoch 530, Loss G: -2.4722, Loss D: -0.0754
# Epoch 531, Loss G: -2.4230, Loss D: -0.0632
# Epoch 532, Loss G: -2.3921, Loss D: 0.0122
# Epoch 533, Loss G: -2.4364, Loss D: -0.1110
# Epoch 534, Loss G: -2.4241, Loss D: 0.0921
# Epoch 535, Loss G: -2.4091, Loss D: 0.0575
# Epoch 536, Loss G: -2.4835, Loss D: 0.0434
# Epoch 537, Loss G: -2.3235, Loss D: -0.1050
# Epoch 538, Loss G: -2.2815, Loss D: 0.0185
# Epoch 539, Loss G: -2.3471, Loss D: -0.0332
# Epoch 540, Loss G: -2.3431, Loss D: -0.0584
# Epoch 541, Loss G: -2.4244, Loss D: -0.0777
# Epoch 542, Loss G: -2.4341, Loss D: -0.0013
# Epoch 543, Loss G: -2.4040, Loss D: 0.0027
# Epoch 544, Loss G: -2.4694, Loss D: 0.0508
# Epoch 545, Loss G: -2.4317, Loss D: 0.0246
# Epoch 546, Loss G: -2.3393, Loss D: 0.0294
# Epoch 547, Loss G: -2.2780, Loss D: 0.0955
# Epoch 548, Loss G: -2.4033, Loss D: -0.0128
# Epoch 549, Loss G: -2.5062, Loss D: -0.0617
# Epoch 550, Loss G: -2.4854, Loss D: 0.0376
# Epoch 551, Loss G: -2.4451, Loss D: -0.0283
# Epoch 552, Loss G: -2.3852, Loss D: -0.0238
# Epoch 553, Loss G: -2.4484, Loss D: 0.0131
# Epoch 554, Loss G: -2.3912, Loss D: 0.0955
# Epoch 555, Loss G: -2.3613, Loss D: 0.0053
# Epoch 556, Loss G: -2.3433, Loss D: 0.0585
# Epoch 557, Loss G: -2.3663, Loss D: -0.0152
# Epoch 558, Loss G: -2.3599, Loss D: 0.0210
# Epoch 559, Loss G: -2.3981, Loss D: 0.0115
# Epoch 560, Loss G: -2.4283, Loss D: 0.0282
# Epoch 561, Loss G: -2.2821, Loss D: -0.0498
# Epoch 562, Loss G: -2.2837, Loss D: -0.0092
# Epoch 563, Loss G: -2.4798, Loss D: 0.0309
# Epoch 564, Loss G: -2.3202, Loss D: -0.0364
# Epoch 565, Loss G: -2.4746, Loss D: 0.0484
# Epoch 566, Loss G: -2.4155, Loss D: 0.0424
# Epoch 567, Loss G: -2.3206, Loss D: 0.0270
# Epoch 568, Loss G: -2.3070, Loss D: -0.0085
# Epoch 569, Loss G: -2.3690, Loss D: 0.0253
# Epoch 570, Loss G: -2.3589, Loss D: 0.0208
# Epoch 571, Loss G: -2.3485, Loss D: 0.0082
# Epoch 572, Loss G: -2.2898, Loss D: -0.0004
# Epoch 573, Loss G: -2.4341, Loss D: -0.1198
# Epoch 574, Loss G: -2.3570, Loss D: 0.0442
# Epoch 575, Loss G: -2.3598, Loss D: -0.0091
# Epoch 576, Loss G: -2.3856, Loss D: -0.1213
# Epoch 577, Loss G: -2.4522, Loss D: 0.0268
# Epoch 578, Loss G: -2.4370, Loss D: -0.0150
# Epoch 579, Loss G: -2.3343, Loss D: -0.0556
# Epoch 580, Loss G: -2.3762, Loss D: -0.0687
# Epoch 581, Loss G: -2.4673, Loss D: -0.0115
# Epoch 582, Loss G: -2.3339, Loss D: -0.0004
# Epoch 583, Loss G: -2.3430, Loss D: 0.0026
# Epoch 584, Loss G: -2.3217, Loss D: -0.1030
# Epoch 585, Loss G: -2.3754, Loss D: -0.0592
# Epoch 586, Loss G: -2.4934, Loss D: 0.0150
# Epoch 587, Loss G: -2.3113, Loss D: 0.0066
# Epoch 588, Loss G: -2.3467, Loss D: -0.0283
# Epoch 589, Loss G: -2.3295, Loss D: 0.0024
# Epoch 590, Loss G: -2.2995, Loss D: -0.0101
# Epoch 591, Loss G: -2.4112, Loss D: -0.0269
# Epoch 592, Loss G: -2.3631, Loss D: -0.0679
# Epoch 593, Loss G: -2.3468, Loss D: 0.0134
# Epoch 594, Loss G: -2.4872, Loss D: -0.0491
# Epoch 595, Loss G: -2.2109, Loss D: 0.0085
# Epoch 596, Loss G: -2.2866, Loss D: -0.0285
# Epoch 597, Loss G: -2.3502, Loss D: 0.0145
# Epoch 598, Loss G: -2.4176, Loss D: -0.0328
# Epoch 599, Loss G: -2.3237, Loss D: 0.0275
# Epoch 600, Loss G: -2.3611, Loss D: 0.0520

# %% [markdown]
# # CTGAN
#
# Adapted from `generate_ctgan_<dataset>.py`

# %%
def sample_CTGAN(df, dataset="occutherm", logs=False):
    # load require samples to balance and initial count
    if dataset == "occutherm":
        # samples to generate per label
        occutherm_req_two = 774
        occutherm_req_one = 647
        occutherm_req_zero = 0 
        occutherm_req_minus_one = 515
        occutherm_req_minus_two = 646
        # count of generated samples per label
        count_two = 0
        count_one = 0
        count_minus_one = 0
        count_minus_two = 0 
    elif dataset == "cresh":
        # samples to generate per label
        cresh_req_nine = 547
        cresh_req_ten = 0
        cresh_req_eleven = 433
        # count of generated samples per label
        count_nine = 0
        count_eleven = 0
    elif dataset == "ashrae":
        # samples to generate per label
        ashrae_req_three = 16173
        ashrae_req_two = 14096
        ashrae_req_one = 10161 
        ashrae_req_zero = 0
        ashrae_req_minus_one = 11695
        ashrae_req_minus_two = 16287
        ashrae_req_minus_three = 17894
        # count of generated samples per label
        count_three = 0
        count_two = 0
        count_one = 0
        count_minus_one = 0
        count_minus_two = 0
        count_minus_three = 0

    samples_count = 0 # total number of samples generated
    finish_loop = False
    
    # samples to generated every loop
    if dataset == "ashrae":
        print_threshold = 10000
    else:
        print_threshold = 1000
    
    # initiliaze synthetic dataframe
    columns = df.columns.values
    df_synth = pd.DataFrame(columns=columns)
    
    # load model
    model_path = "models/ctgan_" + dataset + ".pkl"
    ctgan = pickle.load(open( model_path, "rb" ))

    while True:
        if finish_loop:
            samples_count += print_threshold
            break
        
        # generate `print_threshold` samples
        curr_df = ctgan.sample(print_threshold)
        
        # iterate through the generated samples
        if dataset == "occutherm":
            for index, row in curr_df.iterrows():  
                if (row['Discrete Thermal Comfort_TA'] == 2) and (count_two != occutherm_req_two): 
                    df_synth = df_synth.append(row)
                    count_two += 1 
                elif (row['Discrete Thermal Comfort_TA'] == 1) and (count_one != occutherm_req_one): 
                    df_synth = df_synth.append(row)
                    count_one += 1
                elif (row['Discrete Thermal Comfort_TA'] == -1) and (count_minus_one != occutherm_req_minus_one): 
                    df_synth = df_synth.append(row)
                    count_minus_one += 1
                elif (row['Discrete Thermal Comfort_TA'] == -2) and (count_minus_two != occutherm_req_minus_two): 
                    df_synth = df_synth.append(row)
                    count_minus_two += 1
                elif (count_two == occutherm_req_two) and (count_one == occutherm_req_one) and (count_minus_one == occutherm_req_minus_one) and (count_minus_two == occutherm_req_minus_two):
                    finish_loop = True
                    break
                  
        elif dataset == "cresh":
            for index, row in curr_df.iterrows():  
                if (row['thermal_cozie'] == 9) and (count_nine != cresh_req_nine): 
                    df_synth = df_synth.append(row)
                    count_nine += 1 
                elif (row['thermal_cozie'] == 11) and (count_eleven != cresh_req_eleven): 
                    df_synth = df_synth.append(row)
                    count_eleven += 1
                elif (count_nine == cresh_req_nine) and (count_eleven == cresh_req_eleven):
                    finish_loop = True
                    break

        elif dataset == "ashrae":
            for index, row in curr_df.iterrows(): 
                if (row['Thermal sensation rounded'] == 3) and (count_three != ashrae_req_three): 
                    df_synth = df_synth.append(row)
                    count_three += 1 
                elif (row['Thermal sensation rounded'] == 2) and (count_two != ashrae_req_two): 
                    df_synth = df_synth.append(row)
                    count_two += 1
                elif (row['Thermal sensation rounded'] == 1) and (count_one != ashrae_req_one): 
                    df_synth = df_synth.append(row)
                    count_one += 1
                elif (row['Thermal sensation rounded'] == -1) and (count_minus_one != ashrae_req_minus_one): 
                    df_synth = df_synth.append(row)
                    count_minus_one += 1
                elif (row['Thermal sensation rounded'] == -2) and (count_minus_two != ashrae_req_minus_two): 
                    df_synth = df_synth.append(row)
                    count_minus_two += 1
                elif (row['Thermal sensation rounded'] == -3) and (count_minus_three != ashrae_req_minus_three): 
                    df_synth = df_synth.append(row)
                    count_minus_three += 1
                elif (count_three == ashrae_req_three) and \
                     (count_two == ashrae_req_two) and \
                     (count_one == ashrae_req_one) and \
                     (count_minus_one == ashrae_req_minus_one) and \
                     (count_minus_two == ashrae_req_minus_two) and \
                     (count_minus_three == ashrae_req_minus_three):
                    finish_loop = True
                    break

        samples_count += print_threshold

    if logs:
        print('Original {} train dataset shape {}'.format(df, Counter(y)))        
        print('Resampled (CTGAN) synth dataset shape %s' % Counter(np.array(df_synth.iloc[:, -1])))

    if dataset == "occutherm":
        df_synth['Gender'] = pd.to_numeric(df_synth['Gender'], errors='coerce')
    # last column in float instead of string
    df_synth.iloc[:, -1] = pd.to_numeric(df_synth.iloc[:, -1], errors='coerce')

    return df_synth

# %%
def evaluate_on_dataset(df_train, df_test, dataset='occutherm'):
    model = 'ctgan'
    # empty list to hold values during trials
    variability_list = []
    diversity_list = []

    class_acc_test_list_0 = []
    class_acc_test_list_1 = []
    class_acc_test_list_2 = []
    class_acc_test_list_3 = []
    
    class_report_rdf_list = []
        
    for i in range(0, num_trials):      
        ###################################
        # Sample synthethic dataset for 'dataset'
        df_synth = sample_CTGAN(df_train, dataset)

        # merge synthethic + real dataset
        df_real_synth = pd.concat([df_synth, df_train])
        
        ###################################
        # Variability of generated samples
        variability = evaluation_variability(df_synth)
        variability_list.append(variability)
    
        #################################################
        # Class diversity with respect to the training set
        diversity = evaluation_diversity(df_synth, df_train, baseline=False)
        diversity_list.append(diversity)

        #####################################
        # Quality on the final classification
        # use best models NB, KNN, SVM, RDF
        class_acc_test, class_acc_train, class_models, class_report_rdf = evaluation_classification(df_real_synth, df_test, rdf_depth=fixed_depth, depth_file_name='default', test_size_percentage=test_size_percentage)
        class_acc_test_list_0.append(class_acc_test[0])
        class_acc_test_list_1.append(class_acc_test[1])
        class_acc_test_list_2.append(class_acc_test[2])
        class_acc_test_list_3.append(class_acc_test[3])
        class_report_rdf_list.append(class_report_rdf)
        
        ########################
        # end of for loop trials
        print("End of {} trial".format(i + 1))
        
    # get average of trials
    variability = mean(variability_list)
    diversity = mean(diversity_list)
    class_acc_test = [mean(class_acc_test_list_0), mean(class_acc_test_list_1), mean(class_acc_test_list_2), mean(class_acc_test_list_3)]
    
    #####################################
    # Saving results
    # Format is folder/<dataset_string>-<experiment_name>_<metric or model>_<test or train>_<model>.pkl
    save_pickle(variability, "metrics/" + dataset + "_variability_" + model + "_trials.pkl")
    save_pickle(diversity, "metrics/" + dataset + "_diversity_" + model + "_trials.pkl")
    save_pickle(class_acc_test, "metrics/" + dataset + "_classification_" + model + "_trials.pkl")
    save_pickle(class_report_rdf_list, "label-metrics/" + dataset + "_class_report_" + model + "_trials.pkl")
    
    print("################################################################################")
    print("# Metrics and models for dataset {} saved!".format(dataset))
    print("################################################################################")

# %% [markdown]
# ## Occutherm

# %%
evaluate_on_dataset(df_tcs_train, df_tcs_test, dataset='occutherm')
# Out:
# End of 1 trial
# End of 2 trial
# End of 3 trial
# End of 4 trial
# End of 5 trial
# End of 6 trial
# End of 7 trial
# End of 8 trial
# End of 9 trial
# End of 10 trial
# End of 11 trial
# End of 12 trial
# End of 13 trial
# End of 14 trial
# End of 15 trial
# End of 16 trial
# End of 17 trial
# End of 18 trial
# End of 19 trial
# End of 20 trial
# End of 21 trial
# End of 22 trial
# End of 23 trial
# End of 24 trial
# End of 25 trial
# End of 26 trial
# End of 27 trial
# End of 28 trial
# End of 29 trial
# End of 30 trial
# ################################################################################
# # Metrics and models for dataset occutherm saved!
# ################################################################################

# %% [markdown]
# ## Cresh

# %%
evaluate_on_dataset(df_cresh_train, df_cresh_test, dataset='cresh')
# Out:
# End of 1 trial
# End of 2 trial
# End of 3 trial
# End of 4 trial
# End of 5 trial
# End of 6 trial
# End of 7 trial
# End of 8 trial
# End of 9 trial
# End of 10 trial
# End of 11 trial
# End of 12 trial
# End of 13 trial
# End of 14 trial
# End of 15 trial
# End of 16 trial
# End of 17 trial
# End of 18 trial
# End of 19 trial
# End of 20 trial
# End of 21 trial
# End of 22 trial
# End of 23 trial
# End of 24 trial
# End of 25 trial
# End of 26 trial
# End of 27 trial
# End of 28 trial
# End of 29 trial
# End of 30 trial
# ################################################################################
# # Metrics and models for dataset cresh saved!
# ################################################################################

# %% [markdown]
# ## ASHRAE

# %%
evaluate_on_dataset(df_ashrae_train, df_ashrae_test, dataset='ashrae')
# Out:
# End of 1 trial
# End of 2 trial
# End of 3 trial
# End of 4 trial
# End of 5 trial
# End of 6 trial
# End of 7 trial
# End of 8 trial
# End of 9 trial
# End of 10 trial
# End of 11 trial
# End of 12 trial
# End of 13 trial
# End of 14 trial
# End of 15 trial
# End of 16 trial
# End of 17 trial
# End of 18 trial
# End of 19 trial
# End of 20 trial
# End of 21 trial
# End of 22 trial
# End of 23 trial
# End of 24 trial
# End of 25 trial
# End of 26 trial
# End of 27 trial
# End of 28 trial
# End of 29 trial
# End of 30 trial
# ################################################################################
# # Metrics and models for dataset ashrae saved!
# ################################################################################
